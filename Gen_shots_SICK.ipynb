# %%
import pandas as pd

# %%
df_entail = pd.read_csv("predictions/fewshots/SICK/entails.csv")
df_neutral = pd.read_csv("predictions/fewshots/SICK/neutrals.csv")
df_contradiction = pd.read_csv("predictions/fewshots/SICK/contradictions.csv")

# %%
df_entail.columns
# Out:
# Index(['Unnamed: 0', 'relation', 'no_matcheadas', 'contradiction', 'jaccard',
#        'simBoW', 'sumas', 'mutinf_t', 'max_info_t', 'entail', 'list_comp',
#        'list_incomp', 'Jaro-Winkler_rit', 'negT', 'negH', 'overlap_ent',
#        'clases', 'sentence_A', 'sentence_B'],
#       dtype='object')

# %%
df_entail.describe()
# Out:
#         Unnamed: 0   relation  no_matcheadas  contradiction    jaccard  \
# count    50.000000  50.000000      50.000000           50.0  50.000000
# mean   2160.700000   1.680000       0.169714            0.0   0.730429
# std    1234.014872   0.471212       0.129896            0.0   0.060514
# min     164.000000   1.000000       0.000000            0.0   0.600000
# 25%    1206.500000   1.000000       0.000000            0.0   0.666667
# 50%    2085.500000   2.000000       0.200000            0.0   0.750000
# 75%    3296.750000   2.000000       0.250000            0.0   0.750000
# max    4031.000000   2.000000       0.333333            0.0   0.857143
#
#           simBoW      sumas   mutinf_t  max_info_t     entail  list_comp  \
# count  50.000000  50.000000  50.000000   50.000000  50.000000  50.000000
# mean    0.768086   0.249324   4.520043    0.915500   0.987143   0.780000
# std     0.094971   0.041756   0.102424    0.056235   0.044142   0.418452
# min     0.577350   0.179314   4.309153    0.789560   0.833333   0.000000
# 25%     0.750000   0.210289   4.453073    0.871187   1.000000   1.000000
# 50%     0.774597   0.246054   4.532085    0.918028   1.000000   1.000000
# 75%     0.833333   0.290463   4.571782    0.954233   1.000000   1.000000
# max     0.972306   0.320799   4.719264    1.000000   1.000000   1.000000
#
#        list_incomp  Jaro-Winkler_rit  negT  negH  overlap_ent
# count         50.0         50.000000  50.0  50.0    50.000000
# mean           0.0          0.887255   0.0   0.0     0.830286
# std            0.0          0.095026   0.0   0.0     0.129896
# min            0.0          0.583333   0.0   0.0     0.666667
# 25%            0.0          0.833333   0.0   0.0     0.750000
# 50%            0.0          0.935444   0.0   0.0     0.800000
# 75%            0.0          0.966667   0.0   0.0     1.000000
# max            0.0          0.979167   0.0   0.0     1.000000

# %%
#df=df_entail.sample(n=50)
#df=df_neutral.sample(n=50)
df=df_contradiction.sample(n=50)
df=df.reset_index(drop=True)
df
# Out:
#     Unnamed: 0  relation  no_matcheadas  contradiction   jaccard    simBoW  \
# 0         4075        -1       0.000000       0.166667  0.800000  1.000000
# 1         2121        -1       0.000000       0.250000  0.750000  1.000000
# 2         1860        -1       0.000000       0.250000  0.750000  1.000000
# 3         4261        -1       0.000000       0.333333  0.750000  1.000000
# 4         3484        -1       0.000000       0.250000  0.750000  1.000000
# 5          742        -1       0.000000       0.333333  0.666667  0.866025
# 6         2075        -1       0.000000       0.333333  0.666667  0.866025
# 8           1.000000     0     0     0.750000  CONTRADICTION
# 9           1.000000     0     0     0.800000  CONTRADICTION
# 10          1.000000     0     0     0.666667  CONTRADICTION
# 11          0.933333     0     0     0.666667  CONTRADICTION
# 12          1.000000     0     0     0.750000  CONTRADICTION
# 13          0.958333     0     0     0.714286  CONTRADICTION
# 14          1.000000     0     0     0.750000  CONTRADICTION
# 15          1.000000     0     0     0.666667  CONTRADICTION
# 16          1.000000     0     0     0.666667  CONTRADICTION
# 17          1.000000     0     0     0.500000  CONTRADICTION
# 18          1.000000     0     0     0.666667  CONTRADICTION
# 19          1.000000     0     0     0.666667  CONTRADICTION
# 20          1.000000     0     0     0.750000  CONTRADICTION
# 21          1.000000     0     0     0.666667  CONTRADICTION
# 22          1.000000     0     0     0.666667  CONTRADICTION
# 23          1.000000     0     0     0.750000  CONTRADICTION
# 24          1.000000     0     0     0.666667  CONTRADICTION
# 25          1.000000     0     0     0.666667  CONTRADICTION
# 26          1.000000     0     0     0.750000  CONTRADICTION
# 27          0.916667     0     0     0.666667  CONTRADICTION
# 28          1.000000     0     0     0.666667  CONTRADICTION
# 29          1.000000     0     0     0.666667  CONTRADICTION
# 30          1.000000     0     0     0.666667  CONTRADICTION
# 31          1.000000     0     0     0.750000  CONTRADICTION
# 32          1.000000     0     0     0.750000  CONTRADICTION
# 33          1.000000     0     0     0.666667  CONTRADICTION
# 34          1.000000     0     0     0.750000  CONTRADICTION
# 35          1.000000     0     0     0.714286  CONTRADICTION
# 36          1.000000     0     0     0.750000  CONTRADICTION
# 37          1.000000     0     0     0.750000  CONTRADICTION
# 38          1.000000     0     0     0.750000  CONTRADICTION
# 39          0.916667     0     0     0.666667  CONTRADICTION
# 40          1.000000     0     0     0.750000  CONTRADICTION
# 41          1.000000     0     0     0.750000  CONTRADICTION
# 42          1.000000     0     0     0.666667  CONTRADICTION
# 43          1.000000     0     0     0.750000  CONTRADICTION
# 44          1.000000     0     0     0.750000  CONTRADICTION
# 45          1.000000     0     0     0.666667  CONTRADICTION
# 46          1.000000     0     0     0.750000  CONTRADICTION
# 47          1.000000     0     0     0.800000  CONTRADICTION
# 48          1.000000     0     0     0.750000  CONTRADICTION
# 49          1.000000     0     0     0.800000  CONTRADICTION
#
#                                            sentence_A  \
# 0   There is no dog turning on the grass and pursu...
# 1          There is no man mixing vegetables in a pot
# 2   There is no man rapidly chopping some mushroom...
# 3   There is no black and white dog jumping for a ...
# 4   There is no person riding a bike along a muddy...
# 5                     A kitten is drinking fresh milk
# 6                    A little boy is playing a guitar
# 7   A pet dog is standing on the bank and is looki...
# 8        There is no boy filling a pitcher with water
# 9   There is no brown duck with a green head flapp...
# 10              There is no woman cutting a vegetable
# 11      A cheetah is quickly running behind its prey.
# 12    There is no young boy playing a wind instrument
# 13  A dog which is furry and black is in a back ya...
# 14             A woman is breaking two eggs in a bowl
# 42                       A man is walking in the rain
# 43  There are no dogs of different breeds looking ...
# 44                A man is fixing a silencer to a gun
# 45        A black and white dog is jumping for a ball
# 46  A person wearing grey pants is airborne on a s...
# 47  There is no man squatting in brush and taking ...
# 48                 A panda bear is eating some bamboo
# 49  A man in a suit is standing at a microphone an...

# %% [markdown]
# # Predicciones correctas

# %%
for index,strings in df.iterrows():
    #print(strings["sentence1"],strings["sentence2"],strings['gold_label'])
    prompt = '''Example '''+str(index+1)+'''
    Text: '''+strings["sentence_A"]+'''
    Hypothesis: '''+ strings["sentence_B"]+'''
    features:
    sums:'''+ str(strings["sumas"])+'''
    negH:'''+ str(strings["negH"])+'''
    list_compability:'''+ str(strings["list_comp"])+'''
    list_incompability:'''+ str(strings["list_incomp"])+'''
    relation:'''+ str(strings["relation"])+'''
    entail:'''+ str(strings["entail"])+'''
    negT:'''+ str(strings["negT"])+'''
    mutinf:'''+ str(strings["mutinf_t"])+'''
    contradiction:'''+ str(strings["contradiction"])+'''
    no_matcheadas:'''+ str(strings["no_matcheadas"])+'''
    Jaro-Winkler_rit:'''+ str(strings["Jaro-Winkler_rit"])+'''
    simBoW:'''+ str(strings["simBoW"])+'''
    jaccard:'''+ str(strings["jaccard"])+'''
    overlap_ent:'''+ str(strings["overlap_ent"])+'''
    max_info_t:'''+ str(strings["max_info_t"])+''' 
    Answer:'''+ str(strings["clases"]).upper()+''' 
    '''
    print(prompt)
# Out:
# Example 1
#     Text: There is no dog turning on the grass and pursuing a flying ball
#     Hypothesis: A dog is turning on the grass and pursuing a flying ball
#     features:
#     sums:0.2217856910493638
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.6877460778813616
#     contradiction:0.1666666666666666
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.8
#     overlap_ent:0.8333333333333334
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 2
#     Text: There is no man mixing vegetables in a pot
#     Hypothesis: A man is mixing vegetables in a pot
#     features:
#     sums:0.3309352993965149
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.657386973060493
#     contradiction:0.25
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.75
#     overlap_ent:0.75
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 3
#     Text: There is no man rapidly chopping some mushrooms with a knife
#     Hypothesis: A man is rapidly chopping some mushrooms with a knife
#     features:
#     sums:0.2701420211791992
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.669841697964847
#     contradiction:0.25
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.75
#     overlap_ent:0.75
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 4
#     Text: There is no black and white dog jumping for a ball
#     Hypothesis: A black and white dog is jumping for a ball
#     features:
#     sums:0.293677749633789
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.745841978983128
#     contradiction:0.3333333333333333
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.75
#     overlap_ent:0.6666666666666666
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 5
#     Text: There is no person riding a bike along a muddy trail
#     Hypothesis: A person is riding a bike along a muddy trail
#     features:
#     sums:0.3382354354858398
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.707453588543256
#     contradiction:0.25
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.75
#     overlap_ent:0.75
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 6
#     Text: A kitten is drinking fresh milk
#     Hypothesis: There is no kitten drinking milk
#     features:
#     sums:0.3611617088317871
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.590311868132183
#     contradiction:0.3333333333333333
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:0.9166666666666666
#     simBoW:0.8660254037844387
#     jaccard:0.6666666666666666
#     overlap_ent:0.6666666666666666
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 7
#     Text: A little boy is playing a guitar
#     Hypothesis: There is no boy playing guitar
#     features:
#     sums:0.3493857781092326
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.737388753925916
#     contradiction:0.3333333333333333
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:0.9166666666666666
#     simBoW:0.8660254037844387
#     jaccard:0.6666666666666666
#     overlap_ent:0.6666666666666666
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 8
#     Text: A pet dog is standing on the bank and is looking at another brown dog in the pond
#     Hypothesis: There is no pet dog standing on the bank and looking at another brown dog in the pond
#     features:
#     sums:0.1969919593966737
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.700261027443653
#     contradiction:0.2
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.8
#     overlap_ent:0.8
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 9
#     Text: There is no boy filling a pitcher with water
#     Hypothesis: A boy is filling a pitcher with water
#     features:
#     sums:0.3102125823497772
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.651555817929697
#     contradiction:0.25
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.75
#     overlap_ent:0.75
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 10
#     Text: There is no brown duck with a green head flapping its wings in the water
#     Hypothesis: A brown duck with a green head is flapping its wings in the water
#     features:
#     sums:0.2271384414361447
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.657004116866715
#     contradiction:0.2
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.8
#     overlap_ent:0.8
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 11
#     Text: There is no woman cutting a vegetable
#     Hypothesis: A woman is cutting a vegetable
#     features:
#     sums:0.3636962572733561
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.662729206392783
#     contradiction:0.3333333333333333
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.6666666666666666
#     overlap_ent:0.6666666666666666
#     max_info_t:1.0000000794728596
#     Answer:CONTRADICTION
#
# Example 12
#     Text: A cheetah is quickly running behind its prey.
#     Hypothesis: There is no cheetah quickly running behind its prey
#     features:
#     sums:0.3438689708709717
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.677667071167232
#     contradiction:0.3333333333333333
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:0.9333333333333332
#     simBoW:0.894427190999916
#     jaccard:0.75
#     overlap_ent:0.6666666666666666
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 13
#     Text: There is no young boy playing a wind instrument
#     Hypothesis: A young boy is playing a wind instrument
#     features:
#     sums:0.2977788734436035
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.739482566393367
#     contradiction:0.25
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.6666666666666666
#     overlap_ent:0.75
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 14
#     Text: A dog which is furry and black is in a back yard and is carrying a basket in its mouth
#     Hypothesis: There is no dog which is furry and black in a back yard carrying a basket in its mouth.
#     features:
#     sums:0.1886629611253738
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.676586220010565
#     contradiction:0.1428571428571428
#     no_matcheadas:0.1428571428571428
#     Jaro-Winkler_rit:0.9583333333333334
#     simBoW:0.9354143466934852
#     jaccard:0.8333333333333334
#     overlap_ent:0.7142857142857143
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 15
#     Text: A woman is breaking two eggs in a bowl
#     Hypothesis: There is no woman breaking eggs in a bowl
#     features:
#     sums:0.2389124870300293
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.700427454815631
#     contradiction:0.25
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.75
#     overlap_ent:0.75
#     max_info_t:1.0000001192092896
#     Answer:CONTRADICTION
#
# Example 16
#     Text: There is no woman playing an electric guitar
#     Hypothesis: A woman is playing an electric guitar
#     features:
#     sums:0.3214673697948456
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.713108984101691
#     contradiction:0.3333333333333333
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.6666666666666666
#     overlap_ent:0.6666666666666666
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 17
#     Text: There is no dog running with a volleyball
#     Hypothesis: A dog is running with a volleyball
#     features:
#     sums:0.3637013700273301
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.690039271341549
#     contradiction:0.3333333333333333
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.6666666666666666
#     overlap_ent:0.6666666666666666
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 18
#     Text: There is no man doing back flips on a trampoline
#     Hypothesis: A man is doing back flips on a trampoline
#     features:
#     sums:0.2451745986938476
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.681771760614382
#     contradiction:0.25
#     no_matcheadas:0.25
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.75
#     overlap_ent:0.5
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 19
#     Text: There is no dog rolling from side to side
#     Hypothesis: A dog is rolling from side to side
#     features:
#     sums:0.3599624898698594
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.733647686920332
#     contradiction:0.3333333333333333
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.6666666666666666
#     overlap_ent:0.6666666666666666
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 20
#     Text: There is no dog rolling from side to side
#     Hypothesis: A dog is rolling from side to side
#     features:
#     sums:0.3599624898698594
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.733647686920332
#     contradiction:0.3333333333333333
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.6666666666666666
#     overlap_ent:0.6666666666666666
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 21
#     Text: A woman is breaking two eggs in a bowl
#     Hypothesis: There is no woman breaking eggs in a bowl
#     features:
#     sums:0.2389124870300293
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.700427454815631
#     contradiction:0.25
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.75
#     overlap_ent:0.75
#     max_info_t:1.0000001192092896
#     Answer:CONTRADICTION
#
# Example 22
#     Text: There is no man standing beside a large and colorful birdcage
#     Hypothesis: A man is standing beside a large and colorful birdcage
#     features:
#     sums:0.249949951171875
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.656855866183241
#     contradiction:0.3333333333333333
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.8
#     overlap_ent:0.6666666666666666
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 23
#     Text: There is no woman cutting broccoli
#     Hypothesis: A woman is cutting broccoli
#     features:
#     sums:0.35802337858412
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.756108738859576
#     contradiction:0.3333333333333333
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.6666666666666666
#     overlap_ent:0.6666666666666666
#     max_info_t:1.0000000794728596
#     Answer:CONTRADICTION
#
# Example 24
#     Text: A person is singing and playing the guitar
#     Hypothesis: There is no person singing and playing the guitar
#     features:
#     sums:0.3251639008522033
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.730383651809499
#     contradiction:0.25
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.75
#     overlap_ent:0.75
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 25
#     Text: A man is cutting a potato
#     Hypothesis: There is no man cutting a potato
#     features:
#     sums:0.3454342418246799
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.634758135449879
#     contradiction:0.3333333333333333
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.6666666666666666
#     overlap_ent:0.6666666666666666
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 26
#     Text: A man is recklessly riding a horse
#     Hypothesis: There is no man recklessly riding a horse
#     features:
#     sums:0.3403898775577545
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.633207505372705
#     contradiction:0.3333333333333333
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.6666666666666666
#     overlap_ent:0.6666666666666666
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 27
#     Text: A man is wiping the edge of a bowl
#     Hypothesis: There is no man wiping the edge of a bowl
#     features:
#     sums:0.2792944610118866
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.684742073534983
#     contradiction:0.25
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.75
#     overlap_ent:0.75
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 28
#     Text: A person is wiping butter on a tray
#     Hypothesis: There is no person buttering a tray
#     features:
#     sums:0.2830750544865926
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.651014415508279
#     contradiction:0.3333333333333333
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:0.9166666666666666
#     simBoW:0.8660254037844387
#     jaccard:0.6666666666666666
#     overlap_ent:0.6666666666666666
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 29
#     Text: A man is recklessly riding a horse
#     Hypothesis: There is no man recklessly riding a horse
#     features:
#     sums:0.3403898775577545
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.633207505372705
#     contradiction:0.3333333333333333
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.6666666666666666
#     overlap_ent:0.6666666666666666
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 30
#     Text: There is no man pouring cleaner into the sink
#     Hypothesis: A man is pouring cleaner into the sink
#     features:
#     sums:0.318561851978302
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.638224926405788
#     contradiction:0.3333333333333333
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.75
#     overlap_ent:0.6666666666666666
#     max_info_t:1.0000001192092896
#     Answer:CONTRADICTION
#
# Example 31
#     Text: There is no man cutting a potato
#     Hypothesis: A man is cutting a potato
#     features:
#     sums:0.3454342683156331
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.634758135449879
#     contradiction:0.3333333333333333
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.6666666666666666
#     overlap_ent:0.6666666666666666
#     max_info_t:0.9999999205271404
#     Answer:CONTRADICTION
#
# Example 32
#     Text: There is no man patting an alligator on the mouth
#     Hypothesis: A man is patting an alligator on the mouth
#     features:
#     sums:0.2706350088119507
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.716228198640676
#     contradiction:0.25
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.75
#     overlap_ent:0.75
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 33
#     Text: There are no dogs fighting for a frisbee in a lake
#     Hypothesis: Two dogs are fighting for a frisbee in a lake
#     features:
#     sums:0.2515127658843994
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:0.8
#     negT:0
#     mutinf:4.5110615969394
#     contradiction:0.25
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.75
#     overlap_ent:0.75
#     max_info_t:0.8101742744445801
#     Answer:CONTRADICTION
#
# Example 34
#     Text: There is no man cutting onions
#     Hypothesis: A man is cutting onions
#     features:
#     sums:0.3550994926028781
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.65087714881194
#     contradiction:0.3333333333333333
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.6666666666666666
#     overlap_ent:0.6666666666666666
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 35
#     Text: There is no man fixing a silencer to a gun
#     Hypothesis: A man is fixing a silencer to a gun
#     features:
#     sums:0.3169929981231689
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.717532741602195
#     contradiction:0.25
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.75
#     overlap_ent:0.75
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 36
#     Text: A man is standing in the middle of a gym and is wearing a jersey
#     Hypothesis: There is no man standing in the middle of a gym and is wearing a jersey
#     features:
#     sums:0.2103193071153428
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.676742173777626
#     contradiction:0.1428571428571428
#     no_matcheadas:0.1428571428571428
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.8
#     overlap_ent:0.7142857142857143
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 37
#     Text: A man is wiping the edge of a bowl
#     Hypothesis: There is no man wiping the edge of a bowl
#     features:
#     sums:0.2792944610118866
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.684742073534983
#     contradiction:0.25
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.75
#     overlap_ent:0.75
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 38
#     Text: There is no white dog standing on the leaves on the ground
#     Hypothesis: A white dog is standing on the leaves on the ground
#     features:
#     sums:0.2428314018249511
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.685620442881247
#     contradiction:0.25
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.75
#     overlap_ent:0.75
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 39
#     Text: There is no man rapidly chopping some mushrooms with a knife
#     Hypothesis: A man is rapidly chopping some mushrooms with a knife
#     features:
#     sums:0.2701420211791992
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.669841697964847
#     contradiction:0.25
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.75
#     overlap_ent:0.75
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 40
#     Text: A person is wiping butter on a tray
#     Hypothesis: There is no person buttering a tray
#     features:
#     sums:0.2830750544865926
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.651014415508279
#     contradiction:0.3333333333333333
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:0.9166666666666666
#     simBoW:0.8660254037844387
#     jaccard:0.6666666666666666
#     overlap_ent:0.6666666666666666
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 41
#     Text: There is no man breaking wooden boards with his hand
#     Hypothesis: A man is breaking wooden boards with his hand
#     features:
#     sums:0.2494159698486328
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.646995004227636
#     contradiction:0.25
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.75
#     overlap_ent:0.75
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 42
#     Text: There is no man doing a card trick
#     Hypothesis: A man is doing a card trick
#     features:
#     sums:0.2780289649963379
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.678298845368734
#     contradiction:0.25
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.6666666666666666
#     overlap_ent:0.75
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 43
#     Text: There is no man walking in the rain
#     Hypothesis: A man is walking in the rain
#     features:
#     sums:0.365971565246582
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.752208524478593
#     contradiction:0.3333333333333333
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.6666666666666666
#     overlap_ent:0.6666666666666666
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 44
#     Text: Two dogs of different breeds are looking at each other across a street
#     Hypothesis: There are no dogs of different breeds looking at each other across a street
#     features:
#     sums:0.2565697942461286
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.712789475968664
#     contradiction:0.25
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.75
#     overlap_ent:0.75
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 45
#     Text: There is no man fixing a silencer to a gun
#     Hypothesis: A man is fixing a silencer to a gun
#     features:
#     sums:0.3169929981231689
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.717532741602195
#     contradiction:0.25
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.75
#     overlap_ent:0.75
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 46
#     Text: There is no black and white dog jumping for a ball
#     Hypothesis: A black and white dog is jumping for a ball
#     features:
#     sums:0.293677749633789
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.745841978983128
#     contradiction:0.3333333333333333
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.75
#     overlap_ent:0.6666666666666666
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 47
#     Text: There is no person wearing grey pants who is airborne on a snowboard
#     Hypothesis: A person wearing grey pants is airborne on a snowboard
#     features:
#     sums:0.2196269300248887
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.674277645245603
#     contradiction:0.25
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.6666666666666666
#     overlap_ent:0.75
#     max_info_t:0.9999999205271404
#     Answer:CONTRADICTION
#
# Example 48
#     Text: A man is squatting in brush and taking a photograph
#     Hypothesis: There is no man squatting in brush and taking a photograph
#     features:
#     sums:0.2297369384765625
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.727678735636289
#     contradiction:0.2
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.8
#     overlap_ent:0.8
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 49
#     Text: There is no panda bear eating some bamboo
#     Hypothesis: A panda bear is eating some bamboo
#     features:
#     sums:0.3688361048698425
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.66686208013962
#     contradiction:0.25
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.6666666666666666
#     overlap_ent:0.75
#     max_info_t:1.0
#     Answer:CONTRADICTION
#
# Example 50
#     Text: There is no man in a suit standing at a microphone and singing
#     Hypothesis: A man in a suit is standing at a microphone and singing
#     features:
#     sums:0.2786268615722656
#     negH:0
#     list_compability:0
#     list_incompability:0
#     relation:-1
#     entail:1.0
#     negT:0
#     mutinf:4.646534133317591
#     contradiction:0.2
#     no_matcheadas:0.0
#     Jaro-Winkler_rit:1.0
#     simBoW:1.0
#     jaccard:0.8
#     overlap_ent:0.8
#     max_info_t:1.0
#     Answer:CONTRADICTION
