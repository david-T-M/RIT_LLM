# %%
import pandas as pd

# %%
df_entail = pd.read_csv("predictions/fewshots/Scitail/entails.csv")
#df_neutral = pd.read_csv("predictions/fewshots/MultiNLI/neutrals.csv")
df_contradiction = pd.read_csv("predictions/fewshots/Scitail/contradictions.csv")

# %%
df_entail.columns
# Out:
# Index(['Unnamed: 0', 'relation', 'no_matcheadas', 'contradiction', 'jaccard',
#        'simBoW', 'sumas', 'mutinf_t', 'max_info_t', 'entail', 'list_comp',
#        'list_incomp', 'Jaro-Winkler_rit', 'negT', 'negH', 'overlap_ent',
#        'clases', 'sentence_A', 'sentence_B'],
#       dtype='object')

# %%
df_entail['clases']="ENTAILMENT"

# %%
#df_neutral['clases']="NEUTRAL"

# %%
df_contradiction['clases']="CONTRADICTION"

# %%
df_entail.describe()
# Out:
#          Unnamed: 0  relation  no_matcheadas  contradiction    jaccard  \
# count     50.000000      50.0      50.000000           50.0  50.000000
# mean   11028.580000       2.0       0.466024            0.0   0.423476
# std     5952.526718       0.0       0.121661            0.0   0.137368
# min      738.000000       2.0       0.250000            0.0   0.200000
# 25%     7238.250000       2.0       0.400000            0.0   0.333333
# 50%     9468.000000       2.0       0.500000            0.0   0.400000
# 75%    15758.000000       2.0       0.500000            0.0   0.500000
# max    22137.000000       2.0       0.666667            0.0   0.666667
#
#           simBoW      sumas   mutinf_t  max_info_t     entail  list_comp  \
# count  50.000000  50.000000  50.000000   50.000000  50.000000  50.000000
# mean    0.601693   0.127453   4.345260    0.750575   0.814412   1.320000
# std     0.087192   0.047265   0.087758    0.050353   0.053325   0.471212
# min     0.461880   0.068697   4.124384    0.647613   0.714286   1.000000
# 25%     0.524918   0.090194   4.294287    0.716932   0.777778   1.000000
# 50%     0.606433   0.122813   4.344183    0.751176   0.833333   1.000000
# 75%     0.670154   0.170273   4.401663    0.786701   0.857143   2.000000
# max     0.746004   0.227110   4.518776    0.852371   0.909091   2.000000
#
#        list_incomp  Jaro-Winkler_rit  negT  negH  overlap_ent
# count         50.0         50.000000  50.0  50.0    50.000000
# mean           0.0          0.630667   0.0   0.0     0.533976
# std            0.0          0.077261   0.0   0.0     0.121661
# min            0.0          0.466667   0.0   0.0     0.333333
# 25%            0.0          0.590587   0.0   0.0     0.500000
# 50%            0.0          0.628481   0.0   0.0     0.500000
# 75%            0.0          0.687554   0.0   0.0     0.600000
# max            0.0          0.752381   0.0   0.0     0.750000

# %% [markdown]
# # Predicciones correctas

# %%
df=df_entail.sample(n=50)
#df=df_neutral.sample(n=50)
df=df_contradiction.sample(n=50)
df=df.reset_index(drop=True)

# %%
for index,strings in df.iterrows():
    #print(strings["sentence1"],strings["sentence2"],strings['gold_label'])
    prompt = '''Example '''+str(index+1)+'''
    Text: '''+strings["sentence_A"]+'''
    Hypothesis: '''+ strings["sentence_B"]+'''
    features:
    sums:'''+ str(strings["sumas"])+'''
    negH:'''+ str(strings["negH"])+'''
    list_compability:'''+ str(strings["list_comp"])+'''
    list_incompability:'''+ str(strings["list_incomp"])+'''
    relation:'''+ str(strings["relation"])+'''
    entail:'''+ str(strings["entail"])+'''
    negT:'''+ str(strings["negT"])+'''
    mutinf:'''+ str(strings["mutinf_t"])+'''
    contradiction:'''+ str(strings["contradiction"])+'''
    no_matcheadas:'''+ str(strings["no_matcheadas"])+'''
    Jaro-Winkler_rit:'''+ str(strings["Jaro-Winkler_rit"])+'''
    simBoW:'''+ str(strings["simBoW"])+'''
    jaccard:'''+ str(strings["jaccard"])+'''
    overlap_ent:'''+ str(strings["overlap_ent"])+'''
    max_info_t:'''+ str(strings["max_info_t"])+''' 
    Answer:'''+ str(strings["clases"]).upper()+''' 
    '''
    print(prompt)
# Out:
# Example 1
#     Text: It is this substance that causes the JELL-O &copy; to solidify when cooled.
#     Hypothesis: Continually increasing the pressure on the liquid will eventually cause the substance to solidify.
#     features:
#     sums:0.0810076892375946
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5
#     negT:0
#     mutinf:4.043326053558568
#     contradiction:0.0
#     no_matcheadas:0.5714285714285714
#     Jaro-Winkler_rit:0.561026936026936
#     simBoW:0.4020151261036848
#     jaccard:0.5
#     overlap_ent:0.4285714285714285
#     max_info_t:0.5091725587844849
#     Answer:CONTRADICTION
#
# Example 2
#     Text: Addition of large amounts of organic matter to the soil may also lead to a phenomenon known as &quot;nitrate depression,&quot; where the soluble nitrogen gets incorporated in the bodies of soil decomposers until the carbon of the organic matter is decomposed.
#     Hypothesis: Sediments in oligotrophic lakes contain large amounts of decomposable organic matter.
#     features:
#     sums:0.1127481036716037
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5555555555555556
#     negT:0
#     mutinf:4.121209497634011
#     contradiction:0.0
#     no_matcheadas:0.8
#     Jaro-Winkler_rit:0.4658730158730158
#     simBoW:0.3689323936863109
#     jaccard:0.25
#     overlap_ent:0.2
#     max_info_t:0.6811712053087022
#     Answer:CONTRADICTION
#
# Example 3
#     Text: The dynamic revetment is made of small rocks allowed to move under wave forces to an equilibrium position.
#     Hypothesis: A moving car is said to be in dynamic equilibrium when it is zero net force.
#     features:
#     sums:0.106689994985407
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.625
#     negT:0
#     mutinf:4.253286502518412
#     contradiction:0.0
#     no_matcheadas:0.7142857142857143
#     Jaro-Winkler_rit:0.5518518518518518
#     simBoW:0.4216370213557838
#     jaccard:0.25
#     overlap_ent:0.2857142857142857
#     max_info_t:0.5841854214668274
#     Answer:CONTRADICTION
#
# Example 4
#     Text: If you only have the enzymes, coenzymes, and cytochromes to do enough energy capture to support life by aerobic respiration then you are called an Obligate aerobe.
#     Hypothesis: Aerobic respiration has the advantage of releasing more energy.
#     features:
#     sums:0.0471782403833725
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.7142857142857143
#     negT:0
#     mutinf:4.364430195393774
#     contradiction:0.0
#     no_matcheadas:0.8
#     Jaro-Winkler_rit:0.4111111111111111
#     simBoW:0.3960590171906697
#     jaccard:0.5
#     overlap_ent:0.2
#     max_info_t:0.6808172634669712
#     Answer:CONTRADICTION
#
# Example 5
#     Text: This receptor contains four polypeptide chains ( alpha , beta , and two gammas).
#     Hypothesis: Insulin is made up of two polypeptide chains.
#     features:
#     sums:0.1695642683241102
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.8
#     negT:0
#     mutinf:4.186939007612382
#     contradiction:0.0
#     no_matcheadas:0.75
#     Jaro-Winkler_rit:0.5555555555555555
#     simBoW:0.4008918628686366
#     jaccard:0.5
#     overlap_ent:0.25
#     max_info_t:0.7366508483886719
#     Answer:CONTRADICTION
#
# Example 6
#     Text: Labeling single cells in older embryos 1.
#     Hypothesis: We all start as a single cell and soon grow into a(n) embryo.
#     features:
#     sums:0.0953093341418675
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5714285714285714
#     negT:0
#     mutinf:4.216241087025451
#     contradiction:0.0
#     no_matcheadas:0.8
#     Jaro-Winkler_rit:0.6571428571428571
#     simBoW:0.4780914437337574
#     jaccard:0.1666666666666666
#     overlap_ent:0.2
#     max_info_t:0.5146393775939941
#     Answer:CONTRADICTION
#
# Example 7
#     Text: At the point where each of the capillaries originates from an arteriole, a smooth muscle fiber encircles the capillary.
#     Hypothesis: When the smooth muscle relaxes, the arterioles dilate, allowing blood to enter the capillaries.
#     features:
#     sums:0.0550323666797744
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5555555555555556
#     negT:0
#     mutinf:4.1406097019730845
#     contradiction:0.0
#     no_matcheadas:0.7777777777777778
#     Jaro-Winkler_rit:0.5707070707070706
#     simBoW:0.5929994533288809
#     jaccard:0.5
#     overlap_ent:0.2222222222222222
#     max_info_t:0.5894278950161405
#     Answer:CONTRADICTION
#
# Example 8
#     Text: Conservation of Matter and Stoichiometry The conservation of atoms in chemical reactions leads to the principle of conservation of matter and the ability to calculate the mass of products and reactants.
#     Hypothesis: Atoms make products by rearranging their chemical bonds in a reactant.
#     features:
#     sums:0.0985805313665788
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.7142857142857143
#     negT:0
#     mutinf:4.248277909976251
#     contradiction:0.0
#     no_matcheadas:0.6
#     Jaro-Winkler_rit:0.4677871148459383
#     simBoW:0.3779644730092273
#     jaccard:0.4
#     overlap_ent:0.4
#     max_info_t:0.6491733278547015
#     Answer:CONTRADICTION
#
# Example 9
#     Text: The pulmonary artery plays a crucial role in circulation, pumping oxygen-depleted blood from the heart to the lungs.
#     Hypothesis: After the blood in the pulmonary capillaries becomes saturated with oxygen, it leaves the lungs and travels to the heart.
#     features:
#     sums:0.0972340393949438
#     negH:0
#     list_compability:2
#     list_incompability:0
#     relation:2
#     entail:0.7777777777777778
#     negT:0
#     mutinf:4.20068849387588
#     contradiction:0.0
#     no_matcheadas:0.5555555555555556
#     Jaro-Winkler_rit:0.5819624819624819
#     simBoW:0.544949260913066
#     jaccard:0.375
#     overlap_ent:0.4444444444444444
#     max_info_t:0.6818792555067275
#     Answer:CONTRADICTION
#
# Example 10
#     Text: This longer wavelength energy is absorbed by "greenhouse gases" (notably CO2 and methane) in the atmosphere.
#     Hypothesis: Gases such as co2 and methane can trap thermal energy in earth's atmosphere before radiating it into space.
#     features:
#     sums:0.0675770730683297
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5454545454545454
#     negT:0
#     mutinf:4.1487304311539495
#     contradiction:0.0
#     no_matcheadas:0.6
#     Jaro-Winkler_rit:0.4959595959595959
#     simBoW:0.4387634544762784
#     jaccard:0.1666666666666666
#     overlap_ent:0.4
#     max_info_t:0.6269725886258212
#     Answer:CONTRADICTION
#
# Example 11
#     Text: They are mirror images of each other that differ only in their effect on plane-polarized light.
#     Hypothesis: Plane mirrors work because the light rays create a virtual image behind the mirror.
#     features:
#     sums:0.0882319443755679
#     negH:0
#     list_compability:2
#     list_incompability:0
#     relation:2
#     entail:0.75
#     negT:0
#     mutinf:4.309986465656102
#     contradiction:0.0
#     no_matcheadas:0.7142857142857143
#     Jaro-Winkler_rit:0.5518518518518518
#     simBoW:0.5773502691896258
#     jaccard:0.2
#     overlap_ent:0.2857142857142857
#     max_info_t:0.6163313984870911
#     Answer:CONTRADICTION
#
# Example 12
#     Text: The carbon released during burning takes the form of several gaseous compounds-including carbon dioxide, carbon monoxide, methane, and nonmethane hydrocarbons-and particulate or elemental carbon.
#     Hypothesis: The element carbon on the periodic table forms the most diverse compounds.
#     features:
#     sums:0.0795095413923263
#     negH:0
#     list_compability:2
#     list_incompability:0
#     relation:2
#     entail:0.625
#     negT:0
#     mutinf:4.098866458918385
#     contradiction:0.0
#     no_matcheadas:0.6
#     Jaro-Winkler_rit:0.4444444444444445
#     simBoW:0.3731012536223181
#     jaccard:0.5
#     overlap_ent:0.4
#     max_info_t:0.5846010446548462
#     Answer:CONTRADICTION
#
# Example 13
#     Text: Physical fractionation of soil organic matter in primary particle size and density separates.
#     Hypothesis: Density of matter reflects how closely packed the particles of matter are.
#     features:
#     sums:0.1073612600564956
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6666666666666666
#     negT:0
#     mutinf:4.247386731209983
#     contradiction:0.0
#     no_matcheadas:0.5
#     Jaro-Winkler_rit:0.5492424242424242
#     simBoW:0.4767312946227962
#     jaccard:0.3333333333333333
#     overlap_ent:0.5
#     max_info_t:0.5616077184677124
#     Answer:CONTRADICTION
#
# Example 14
#     Text: Helpful Hint: Wrap the cactus with a rolled up newspaper to prevent the spines from piercing your fingers.
#     Hypothesis: The spines of a cactus help it survive because spines protect the cactus from animals.
#     features:
#     sums:0.0579935818910598
#     negH:0
#     list_compability:2
#     list_incompability:0
#     relation:2
#     entail:0.6666666666666666
#     negT:0
#     mutinf:4.193300761046522
#     contradiction:0.0
#     no_matcheadas:0.7142857142857143
#     Jaro-Winkler_rit:0.5574074074074075
#     simBoW:0.4003203845127179
#     jaccard:0.2
#     overlap_ent:0.2857142857142857
#     max_info_t:0.5662837425867716
#     Answer:CONTRADICTION
#
# Example 15
#     Text: We are currently learning about evolution...you know, microevolution and macroevolution and the like.
#     Hypothesis: Evolution that occurs over a short period of time is known as microevolution.
#     features:
#     sums:0.1256380535307384
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5714285714285714
#     negT:0
#     mutinf:4.173949775981745
#     contradiction:0.0
#     no_matcheadas:0.8
#     Jaro-Winkler_rit:0.4444444444444444
#     simBoW:0.5051814855409226
#     jaccard:0.25
#     overlap_ent:0.2
#     max_info_t:0.5351760728018624
#     Answer:CONTRADICTION
#
# Example 16
#     Text: His art seeks to combine his memories of the South with specific, often religious, associations.
#     Hypothesis: Specific scents are often associated with memories.
#     features:
#     sums:0.0959445198376973
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.8
#     negT:0
#     mutinf:4.388921147368793
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.4303030303030303
#     simBoW:0.3721042037676254
#     jaccard:0.3333333333333333
#     overlap_ent:0.3333333333333333
#     max_info_t:0.6957564353942871
#     Answer:CONTRADICTION
#
# Example 17
#     Text: Some of these substances can burn - for example, organic lead compounds in some gasolines.
#     Hypothesis: Wood burning is an example of a different substance being formed.
#     features:
#     sums:0.1240076018231255
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6666666666666666
#     negT:0
#     mutinf:4.218417143434896
#     contradiction:0.0
#     no_matcheadas:0.6
#     Jaro-Winkler_rit:0.6047619047619048
#     simBoW:0.4780914437337574
#     jaccard:0.3333333333333333
#     overlap_ent:0.4
#     max_info_t:0.5915650924046835
#     Answer:CONTRADICTION
#
# Example 18
#     Text: The Hb S allele contains a one nucleotide deletion.
#     Hypothesis: Deletions remove one or more nucleotides from the dna
#     features:
#     sums:0.140049010515213
#     negH:0
#     list_compability:2
#     list_incompability:0
#     relation:2
#     entail:0.8333333333333334
#     negT:0
#     mutinf:4.261351506221397
#     contradiction:0.0
#     no_matcheadas:0.8
#     Jaro-Winkler_rit:0.4285714285714285
#     simBoW:0.3779644730092272
#     jaccard:0.2
#     overlap_ent:0.2
#     max_info_t:0.7127315203348795
#     Answer:CONTRADICTION
#
# Example 19
#     Text: Meteorites formed outside the solar system.
#     Hypothesis: Meteorites, formed of split asteroids or planetary rocks, provide clues about our solar system.
#     features:
#     sums:0.1035754308104515
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5
#     negT:0
#     mutinf:4.093250240921293
#     contradiction:0.0
#     no_matcheadas:0.5714285714285714
#     Jaro-Winkler_rit:0.4957264957264957
#     simBoW:0.5270462766947299
#     jaccard:0.3333333333333333
#     overlap_ent:0.4285714285714285
#     max_info_t:0.5579108238220215
#     Answer:CONTRADICTION
#
# Example 20
#     Text: The carbon released during burning takes the form of several gaseous compounds-including carbon dioxide, carbon monoxide, methane, and nonmethane hydrocarbons-and particulate or elemental carbon.
#     Hypothesis: The element carbon on the periodic table forms the most diverse compounds.
#     features:
#     sums:0.0795095413923263
#     negH:0
#     list_compability:2
#     list_incompability:0
#     relation:2
#     entail:0.625
#     negT:0
#     mutinf:4.098866458918385
#     contradiction:0.0
#     no_matcheadas:0.6
#     Jaro-Winkler_rit:0.4444444444444445
#     simBoW:0.3731012536223181
#     jaccard:0.5
#     overlap_ent:0.4
#     max_info_t:0.5846010446548462
#     Answer:CONTRADICTION
#
# Example 21
#     Text: In PETSc, the operation to copy components of one vector to another vector is called a scatter.
#     Hypothesis: An organism that carries pathogens from one individual to another is called a vector.
#     features:
#     sums:0.0636758096516132
#     negH:0
#     list_compability:2
#     list_incompability:0
#     relation:2
#     entail:0.7142857142857143
#     negT:0
#     mutinf:4.157959861905519
#     contradiction:0.0
#     no_matcheadas:0.5714285714285714
#     Jaro-Winkler_rit:0.465079365079365
#     simBoW:0.4364357804719847
#     jaccard:0.4
#     overlap_ent:0.4285714285714285
#     max_info_t:0.5717904227120536
#     Answer:CONTRADICTION
#
# Example 22
#     Text: environmental factors and interactions among microbes as structuring forces in natural communities;
#     Hypothesis: Community interactions are important factors in natural selection.
#     features:
#     sums:0.0875833928585052
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.8333333333333334
#     negT:0
#     mutinf:4.397492654002199
#     contradiction:0.0
#     no_matcheadas:0.5
#     Jaro-Winkler_rit:0.4761904761904761
#     simBoW:0.5039526306789696
#     jaccard:0.3333333333333333
#     overlap_ent:0.5
#     max_info_t:0.7435510953267416
#     Answer:CONTRADICTION
#
# Example 23
#     Text: It aids in the passage of kidney stones and is used in combination with other diuretic herbs for kidney treatments which assist in the release of gravel and stones.
#     Hypothesis: The option to remove kidney stones other than surgery is ultrasound treatments.
#     features:
#     sums:0.0567313111745394
#     negH:0
#     list_compability:2
#     list_incompability:0
#     relation:2
#     entail:0.75
#     negT:0
#     mutinf:4.228514997379074
#     contradiction:0.0
#     no_matcheadas:0.75
#     Jaro-Winkler_rit:0.5119047619047619
#     simBoW:0.5
#     jaccard:0.3333333333333333
#     overlap_ent:0.25
#     max_info_t:0.6326494812965393
#     Answer:CONTRADICTION
#
# Example 24
#     Text: The word profession comes from the Latin professus, meaning to have affirmed publicly.
#     Hypothesis: The term "science" comes from a latin word that means having knowledge.
#     features:
#     sums:0.0634474977850914
#     negH:0
#     list_compability:2
#     list_incompability:0
#     relation:2
#     entail:0.75
#     negT:0
#     mutinf:4.211844909351617
#     contradiction:0.0
#     no_matcheadas:0.5714285714285714
#     Jaro-Winkler_rit:0.6318181818181818
#     simBoW:0.4385290096535146
#     jaccard:0.4
#     overlap_ent:0.4285714285714285
#     max_info_t:0.6518992781639099
#     Answer:CONTRADICTION
#
# Example 25
#     Text: A polypeptide chain containing at least two types of catalytic domains.
#     Hypothesis: Insulin is made up of two polypeptide chains.
#     features:
#     sums:0.141840468512641
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.8
#     negT:0
#     mutinf:4.221140144922163
#     contradiction:0.0
#     no_matcheadas:0.75
#     Jaro-Winkler_rit:0.5952380952380952
#     simBoW:0.5669467095138409
#     jaccard:0.5
#     overlap_ent:0.25
#     max_info_t:0.7328838348388672
#     Answer:CONTRADICTION
#
# Example 26
#     Text: Each molecule is composed of four polypeptide chains--two identical heavy chains and two identical light chains.
#     Hypothesis: Insulin is made up of two polypeptide chains.
#     features:
#     sums:0.1639569388495551
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.8
#     negT:0
#     mutinf:4.175150733599651
#     contradiction:0.0
#     no_matcheadas:0.5
#     Jaro-Winkler_rit:0.5512820512820512
#     simBoW:0.5212860351426869
#     jaccard:0.5
#     overlap_ent:0.5
#     max_info_t:0.7546952724456787
#     Answer:CONTRADICTION
#
# Example 27
#     Text: The worm SOUND becomes unbearably loud.
#     Hypothesis: Amplified, it becomes louder happens do the sound during a resonance.
#     features:
#     sums:0.0645588074411664
#     negH:0
#     list_compability:2
#     list_incompability:0
#     relation:2
#     entail:0.7142857142857143
#     negT:0
#     mutinf:4.082700728911429
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.4785714285714286
#     simBoW:0.50709255283711
#     jaccard:0.1666666666666666
#     overlap_ent:0.3333333333333333
#     max_info_t:0.6189752306256976
#     Answer:CONTRADICTION
#
# Example 28
#     Text: Bears have five digits on each dextrous paw, each digit with a long non-retractable claw.
#     Hypothesis: Primates have five digits on each extremity.
#     features:
#     sums:0.0671590068123557
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.8
#     negT:0
#     mutinf:4.365428712545532
#     contradiction:0.0
#     no_matcheadas:0.5
#     Jaro-Winkler_rit:0.4722222222222221
#     simBoW:0.4008918628686366
#     jaccard:0.5
#     overlap_ent:0.5
#     max_info_t:0.695600175857544
#     Answer:CONTRADICTION
#
# Example 29
#     Text: Most abundant is the cholla or buckhorn cactus - thin green arms well protected by spines.
#     Hypothesis: The spines of a cactus help it survive because spines protect the cactus from animals.
#     features:
#     sums:0.0642915639010342
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6666666666666666
#     negT:0
#     mutinf:4.285121764722113
#     contradiction:0.0
#     no_matcheadas:0.7142857142857143
#     Jaro-Winkler_rit:0.4776936026936026
#     simBoW:0.5017452060042544
#     jaccard:0.2
#     overlap_ent:0.2857142857142857
#     max_info_t:0.600379467010498
#     Answer:CONTRADICTION
#
# Example 30
#     Text: The glucosinolate-myrosinase system is assumed to play a role in plant-herbivore and plant-pathogen interactions.
#     Hypothesis: Plants face two types of enemies: herbivores and pathogens.
#     features:
#     sums:0.0694183319807052
#     negH:0
#     list_compability:2
#     list_incompability:0
#     relation:2
#     entail:0.7142857142857143
#     negT:0
#     mutinf:4.111771285882083
#     contradiction:0.0
#     no_matcheadas:0.5
#     Jaro-Winkler_rit:0.4694444444444444
#     simBoW:0.3686048903872427
#     jaccard:0.25
#     overlap_ent:0.5
#     max_info_t:0.4962908199855259
#     Answer:CONTRADICTION
#
# Example 31
#     Text: An accomplishment, which, were it to be realized, would render history rational in the same scientific sense that Newton had applied to physics and science.
#     Hypothesis: In science, something that always applies under the same conditions is called a scientific law.
#     features:
#     sums:0.0956849865615367
#     negH:0
#     list_compability:2
#     list_incompability:0
#     relation:2
#     entail:0.75
#     negT:0
#     mutinf:4.2549300865057225
#     contradiction:0.0
#     no_matcheadas:0.8
#     Jaro-Winkler_rit:0.4694444444444444
#     simBoW:0.5400617248673216
#     jaccard:0.1666666666666666
#     overlap_ent:0.2
#     max_info_t:0.597021758556366
#     Answer:CONTRADICTION
#
# Example 32
#     Text: A tube-shaped canal in the digestive tract between the pharynx and the stomach.
#     Hypothesis: The pharynx is the name of the tube that joins the mouth to the digestive and respiratory tracts.
#     features:
#     sums:0.1475328377314976
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.625
#     negT:0
#     mutinf:4.138102178850978
#     contradiction:0.0
#     no_matcheadas:0.5
#     Jaro-Winkler_rit:0.6481481481481481
#     simBoW:0.5892556509887896
#     jaccard:0.2857142857142857
#     overlap_ent:0.5
#     max_info_t:0.630035400390625
#     Answer:CONTRADICTION
#
# Example 33
#     Text: use of a single uppercase letter is encouraged.
#     Hypothesis: When represented by a single letter, dominant alleles are represented by uppercase letters.
#     features:
#     sums:0.0992031176884969
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6666666666666666
#     negT:0
#     mutinf:4.223725060459526
#     contradiction:0.0
#     no_matcheadas:0.75
#     Jaro-Winkler_rit:0.6055555555555555
#     simBoW:0.5455447255899809
#     jaccard:0.3333333333333333
#     overlap_ent:0.25
#     max_info_t:0.5650485754013062
#     Answer:CONTRADICTION
#
# Example 34
#     Text: Collagen is a protein, an important part of connective tissue, and is the most common protein in the body.
#     Hypothesis: Protein is an important part of a healthy diet because it is needed to repair tissue.
#     features:
#     sums:0.0775785711076524
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.625
#     negT:0
#     mutinf:4.186702747817964
#     contradiction:0.0
#     no_matcheadas:0.625
#     Jaro-Winkler_rit:0.5795454545454546
#     simBoW:0.4564354645876385
#     jaccard:0.4
#     overlap_ent:0.375
#     max_info_t:0.625051736831665
#     Answer:CONTRADICTION
#
# Example 35
#     Text: The bacterial plasma membrane is also a permeability barrier, and it contains a variety of different transport proteins that selectively mediate the passage of substances into and out of the cell.
#     Hypothesis: Passive transport occurs when substances cross the plasma membrane without any input of energy from the cell.
#     features:
#     sums:0.0586980571349461
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6
#     negT:0
#     mutinf:4.2850688246700175
#     contradiction:0.0
#     no_matcheadas:0.6
#     Jaro-Winkler_rit:0.4939096850861557
#     simBoW:0.4387634544762784
#     jaccard:0.1666666666666666
#     overlap_ent:0.4
#     max_info_t:0.6020788669586181
#     Answer:CONTRADICTION
#
# Example 36
#     Text: Collagen is a protein, an important part of connective tissue, and is the most common protein in the body.
#     Hypothesis: Protein is an important part of a healthy diet because it is needed to repair tissue.
#     features:
#     sums:0.0775785711076524
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.625
#     negT:0
#     mutinf:4.186702747817964
#     contradiction:0.0
#     no_matcheadas:0.625
#     Jaro-Winkler_rit:0.5795454545454546
#     simBoW:0.4564354645876385
#     jaccard:0.4
#     overlap_ent:0.375
#     max_info_t:0.625051736831665
#     Answer:CONTRADICTION
#
# Example 37
#     Text: Much of the skull is formed from cartilage, and its overall structure is reduced.
#     Hypothesis: Hagfishes have a skull made of cartilage.
#     features:
#     sums:0.1119129928095
#     negH:0
#     list_compability:2
#     list_incompability:0
#     relation:2
#     entail:0.8
#     negT:0
#     mutinf:4.057213491889831
#     contradiction:0.0
#     no_matcheadas:0.6
#     Jaro-Winkler_rit:0.5972222222222222
#     simBoW:0.5303300858899106
#     jaccard:0.5
#     overlap_ent:0.4
#     max_info_t:0.5626058101654052
#     Answer:CONTRADICTION
#
# Example 38
#     Text: The molecules of real compounds attract each other.
#     Hypothesis: Compared with the molecules of many other substances, molecules of water are strongly attracted to each other.
#     features:
#     sums:0.0630953470865885
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5
#     negT:0
#     mutinf:4.105465788854668
#     contradiction:0.0
#     no_matcheadas:0.8
#     Jaro-Winkler_rit:0.437037037037037
#     simBoW:0.5393598899705937
#     jaccard:0.4
#     overlap_ent:0.2
#     max_info_t:0.5216209292411804
#     Answer:CONTRADICTION
#
# Example 39
#     Text: In most species there is a swimming veliger larva with a coiled shell which is shed at metamorphosis when the larva transforms into the adult form.
#     Hypothesis: Fish hatch into larvae that are different from the adult form of species.
#     features:
#     sums:0.0494045501663571
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5714285714285714
#     negT:0
#     mutinf:4.242892618689519
#     contradiction:0.0
#     no_matcheadas:0.5
#     Jaro-Winkler_rit:0.4241452991452991
#     simBoW:0.3651483716701107
#     jaccard:0.3333333333333333
#     overlap_ent:0.5
#     max_info_t:0.6922999790736607
#     Answer:CONTRADICTION
#
# Example 40
#     Text: Much of the skull is formed from cartilage, and its overall structure is reduced.
#     Hypothesis: Hagfishes have a skull made of cartilage.
#     features:
#     sums:0.1119129928095
#     negH:0
#     list_compability:2
#     list_incompability:0
#     relation:2
#     entail:0.8
#     negT:0
#     mutinf:4.057213491889831
#     contradiction:0.0
#     no_matcheadas:0.6
#     Jaro-Winkler_rit:0.5972222222222222
#     simBoW:0.5303300858899106
#     jaccard:0.5
#     overlap_ent:0.4
#     max_info_t:0.5626058101654052
#     Answer:CONTRADICTION
#
# Example 41
#     Text: Because CO2 absorbs energy emitted from the Earth and prevents it from going back out into space, it is called a greenhouse gas.
#     Hypothesis: Gases such as co2 and methane can trap thermal energy in earth's atmosphere before radiating it into space.
#     features:
#     sums:0.1017085374003709
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5454545454545454
#     negT:0
#     mutinf:4.143007017875337
#     contradiction:0.0
#     no_matcheadas:0.7
#     Jaro-Winkler_rit:0.5797202797202797
#     simBoW:0.5017452060042544
#     jaccard:0.3333333333333333
#     overlap_ent:0.3
#     max_info_t:0.6703551465814764
#     Answer:CONTRADICTION
#
# Example 42
#     Text: The development of the throwing stick ( atlatl ) with projectile points increased the killing range of the hunter.
#     Hypothesis: Range is the term for the horizontal displacement of a projectile from its starting point.
#     features:
#     sums:0.0645311287471226
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5714285714285714
#     negT:0
#     mutinf:4.222105125555235
#     contradiction:0.0
#     no_matcheadas:0.5
#     Jaro-Winkler_rit:0.5352564102564102
#     simBoW:0.3922322702763681
#     jaccard:0.2
#     overlap_ent:0.5
#     max_info_t:0.5519416672842843
#     Answer:CONTRADICTION
#
# Example 43
#     Text: By 1997, researchers took it a step further, zeroing in on a specific gene on chromosome 4 which codes for alpha-synuclein, a nervous system protein.
#     Hypothesis: Genes, or functional units of chromosomes, determine specific characteristics by coding for specific proteins.
#     features:
#     sums:0.0529531331525908
#     negH:0
#     list_compability:2
#     list_incompability:0
#     relation:2
#     entail:0.7777777777777778
#     negT:0
#     mutinf:4.258542293278111
#     contradiction:0.0
#     no_matcheadas:0.5714285714285714
#     Jaro-Winkler_rit:0.5844729344729345
#     simBoW:0.6183469424008423
#     jaccard:0.2
#     overlap_ent:0.4285714285714285
#     max_info_t:0.6806594530741373
#     Answer:CONTRADICTION
#
# Example 44
#     Text: The implications of both positive and negative test results should be reiterated when the results are communicated.
#     Hypothesis: We call an incorrect test result that should have been positive a(n) false negative.
#     features:
#     sums:0.1241369588034493
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.625
#     negT:0
#     mutinf:4.289743774853983
#     contradiction:0.0
#     no_matcheadas:0.75
#     Jaro-Winkler_rit:0.4898148148148148
#     simBoW:0.5720775535473555
#     jaccard:0.2
#     overlap_ent:0.25
#     max_info_t:0.6174784898757935
#     Answer:CONTRADICTION
#
# Example 45
#     Text: The cells also need oxygen for this series of biochemical reactions.
#     Hypothesis: Biochemical reactions take place inside the organisms' cells.
#     features:
#     sums:0.1460234664735339
#     negH:0
#     list_compability:2
#     list_incompability:0
#     relation:2
#     entail:0.8333333333333334
#     negT:0
#     mutinf:4.173355302213964
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.4226190476190476
#     simBoW:0.5345224838248488
#     jaccard:0.5
#     overlap_ent:0.3333333333333333
#     max_info_t:0.6274596055348715
#     Answer:CONTRADICTION
#
# Example 46
#     Text: At the point where each of the capillaries originates from an arteriole, a smooth muscle fiber encircles the capillary.
#     Hypothesis: When the smooth muscle relaxes, the arterioles dilate, allowing blood to enter the capillaries.
#     features:
#     sums:0.0550323666797744
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5555555555555556
#     negT:0
#     mutinf:4.1406097019730845
#     contradiction:0.0
#     no_matcheadas:0.7777777777777778
#     Jaro-Winkler_rit:0.5707070707070706
#     simBoW:0.5929994533288809
#     jaccard:0.5
#     overlap_ent:0.2222222222222222
#     max_info_t:0.5894278950161405
#     Answer:CONTRADICTION
#
# Example 47
#     Text: A process in which substances are transported across a plasma membrane with the concentration gradient with the aid
#     Hypothesis: Primary active transport involves the forcing of a substance into a cell against its concentration gradient.
#     features:
#     sums:0.0679378625419404
#     negH:0
#     list_compability:2
#     list_incompability:0
#     relation:2
#     entail:0.6666666666666666
#     negT:0
#     mutinf:4.177805079115181
#     contradiction:0.0
#     no_matcheadas:0.7142857142857143
#     Jaro-Winkler_rit:0.6083333333333333
#     simBoW:0.4472135954999578
#     jaccard:0.1666666666666666
#     overlap_ent:0.2857142857142857
#     max_info_t:0.5569070710076226
#     Answer:CONTRADICTION
#
# Example 48
#     Text: Stretch marks occur in the dermis, the middle skin layer which contains the kin's elastic proteins that allowing the skin to stretch and return to its original shape.
#     Hypothesis: Most skin structures originate in the dermis.
#     features:
#     sums:0.1101524475216865
#     negH:0
#     list_compability:2
#     list_incompability:0
#     relation:2
#     entail:0.8
#     negT:0
#     mutinf:4.155517496396476
#     contradiction:0.0
#     no_matcheadas:0.5
#     Jaro-Winkler_rit:0.5035087719298246
#     simBoW:0.3730019232961254
#     jaccard:0.3333333333333333
#     overlap_ent:0.5
#     max_info_t:0.6038583278656006
#     Answer:CONTRADICTION
#
# Example 49
#     Text: If initially the free electron was generated by some light incident on the material then the process is called luminescence induced by light or photoluminescence.
#     Hypothesis: Producing light without a high temperature is called luminescence.
#     features:
#     sums:0.1201788706657214
#     negH:0
#     list_compability:2
#     list_incompability:0
#     relation:2
#     entail:0.8333333333333334
#     negT:0
#     mutinf:4.276191405471016
#     contradiction:0.0
#     no_matcheadas:0.6
#     Jaro-Winkler_rit:0.5773809523809524
#     simBoW:0.472455591261534
#     jaccard:0.5
#     overlap_ent:0.4
#     max_info_t:0.6619956096013387
#     Answer:CONTRADICTION
#
# Example 50
#     Text: The possible measurement error in many cold fusion experiments today are much, much smaller than the huge effects being measured.
#     Hypothesis: You decrease errors in an experiment by take many measurements.
#     features:
#     sums:0.0446989169487586
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.8333333333333334
#     negT:0
#     mutinf:4.378066895380537
#     contradiction:0.0
#     no_matcheadas:0.6
#     Jaro-Winkler_rit:0.4435897435897435
#     simBoW:0.4961389383568337
#     jaccard:0.2
#     overlap_ent:0.4
#     max_info_t:0.7362998326619467
#     Answer:CONTRADICTION
