# %%
import pandas as pd

# %%
df_entail = pd.read_csv("predictions/fewshots/SNLI/entails.csv")
df_neutral = pd.read_csv("predictions/fewshots/SNLI/neutrals.csv")
df_contradiction = pd.read_csv("predictions/fewshots/SNLI/contradictions.csv")

# %%
df_entail.columns
# Out:
# Index(['Unnamed: 0', 'relation', 'no_matcheadas', 'contradiction', 'jaccard',
#        'simBoW', 'sumas', 'mutinf_t', 'max_info_t', 'entail', 'list_comp',
#        'list_incomp', 'Jaro-Winkler_rit', 'negT', 'negH', 'overlap_ent',
#        'clases', 'sentence_A', 'sentence_B'],
#       dtype='object')

# %%
df_entail.describe()
# Out:
#          Unnamed: 0  relation  no_matcheadas  contradiction    jaccard  \
# count      50.00000      50.0      50.000000           50.0  50.000000
# mean   289713.68000       2.0       0.393833            0.0   0.570571
# std    144387.99222       0.0       0.139959            0.0   0.160001
# min     10584.00000       2.0       0.125000            0.0   0.250000
# 25%    163370.00000       2.0       0.333333            0.0   0.500000
# 50%    306062.50000       2.0       0.333333            0.0   0.550000
# 75%    406230.00000       2.0       0.500000            0.0   0.666667
# max    530826.00000       2.0       0.666667            0.0   0.833333
#
#           simBoW      sumas   mutinf_t  max_info_t     entail  list_comp  \
# count  50.000000  50.000000  50.000000   50.000000  50.000000  50.000000
# mean    0.531223   0.161992   4.445676    0.815174   0.906810   0.720000
# std     0.103870   0.041904   0.118906    0.104876   0.126376   0.453557
# min     0.348155   0.087297   4.181937    0.580176   0.666667   0.000000
# 25%     0.460178   0.132152   4.360317    0.735511   0.800000   0.000000
# 50%     0.530330   0.159447   4.450190    0.821805   1.000000   1.000000
# 75%     0.609279   0.191574   4.533589    0.910751   1.000000   1.000000
# max     0.727273   0.251660   4.636346    0.971981   1.000000   1.000000
#
#        list_incomp  Jaro-Winkler_rit  negT  negH  overlap_ent
# count         50.0         50.000000  50.0  50.0    50.000000
# mean           0.0          0.621484   0.0   0.0     0.606167
# std            0.0          0.118601   0.0   0.0     0.139959
# min            0.0          0.420370   0.0   0.0     0.333333
# 25%            0.0          0.535025   0.0   0.0     0.500000
# 50%            0.0          0.583333   0.0   0.0     0.666667
# 75%            0.0          0.727369   0.0   0.0     0.666667
# max            0.0          0.805556   0.0   0.0     0.875000

# %%
#df=df_entail.sample(n=50)
#df=df_neutral.sample(n=50)
df=df_contradiction.sample(n=50)
df=df.reset_index(drop=True)
df
# Out:
#     Unnamed: 0  relation  no_matcheadas  contradiction   jaccard    simBoW  \
# 0       374763         2       0.750000            0.0  0.250000  0.365148
# 1       434322         2       0.750000            0.0  0.500000  0.316228
# 2       232609         2       0.666667            0.0  0.333333  0.333333
# 3       151867         2       0.500000            0.0  0.250000  0.447214
# 4        77097         2       0.666667            0.0  0.333333  0.288675
# 5       441155         2       0.500000            0.0  0.333333  0.474342
# 6        91785         2       0.666667            0.0  0.250000  0.428571
# 7       435100         2       0.666667            0.0  0.333333  0.344124
# 8       465769         2       0.666667            0.0  0.333333  0.316228
# 9       276524         2       0.750000            0.0  0.333333  0.400000
# 10      512596         2       0.714286            0.0  0.166667  0.400892
# 11      309729         2       0.500000            0.0  0.500000  0.372104
# 12      221951         2       0.750000            0.0  0.333333  0.267261
# 13      116519         2       0.500000            0.0  0.500000  0.447214
# 14       20873         2       0.500000            0.0  0.500000  0.500000
# 15      523124         2       0.666667            0.0  0.333333  0.258199
# 16      254792         2       0.666667            0.0  0.333333  0.316228
# 17      363658         2       0.600000            0.0  0.333333  0.433013
# 18      123503         2       0.666667            0.0  0.500000  0.365148
# 19      181048         2       0.666667            0.0  0.333333  0.408248
# 20      266825         2       0.750000            0.0  0.250000  0.308607
# 21       25474         2       0.857143            0.0  0.200000  0.341882
# 22      132195         2       0.750000            0.0  0.333333  0.375000
# 23      170076         2       0.666667            0.0  0.500000  0.288675
# 24      221654         2       0.600000            0.0  0.400000  0.547723
# 25       81150         2       0.666667            0.0  0.333333  0.250000
# 26      257205         2       0.750000            0.0  0.333333  0.258199
# 27      293576         2       0.666667            0.0  0.250000  0.250000
# 28      325209         2       0.666667            0.0  0.333333  0.333333
# 29      309858         2       0.666667            0.0  0.500000  0.288675
# 30       81895         2       0.600000            0.0  0.400000  0.390360
# 31      185995         2       0.600000            0.0  0.250000  0.363803
# 32       72323         2       0.500000            0.0  0.500000  0.408248
# 33      287631         2       0.666667            0.0  0.333333  0.263117
# 34       71588         2       0.666667            0.0  0.333333  0.408248
# 35       15650         2       0.666667            0.0  0.333333  0.223607
# 36      104723         2       0.750000            0.0  0.250000  0.338062
# 37      132940         2       0.666667            0.0  0.333333  0.377964
# 38       54500         2       0.666667            0.0  0.333333  0.400892
# 39        8077         2       0.666667            0.0  0.333333  0.218218
# 40      518604         2       0.666667            0.0  0.333333  0.218218
# 41      476371         2       0.750000            0.0  0.250000  0.400000
# 42      116313         2       0.666667            0.0  0.333333  0.288675
# 43      365406         2       0.750000            0.0  0.333333  0.500000
# 44      521399         2       0.800000            0.0  0.500000  0.547723
# 45      101467         2       0.500000            0.0  0.500000  0.408248
# 46      414324         2       0.666667            0.0  0.500000  0.408248
# 47      242071         2       0.750000            0.0  0.250000  0.339683
# 48      396402         2       0.666667            0.0  0.333333  0.377964
# 49      257916         2       0.833333            0.0  0.200000  0.308607
#
#        sumas  mutinf_t  max_info_t    entail  list_comp  list_incomp  \
# 0   0.072658  4.084341    0.429684  0.500000          1            0
# 1   0.030320  4.063042    0.349870  0.500000          1            0
# 2   0.090939  4.131163    0.429169  0.666667          1            0
# 3   0.130461  4.343208    0.645601  0.750000          1            0
# 4   0.056171  4.093555    0.419056  0.666667          1            0
# 5   0.129080  4.336449    0.633776  0.750000          1            0
# 6   0.110858  4.023240    0.446619  0.500000          1            0
# 7   0.050512  4.127776    0.400003  0.666667          1            0
# 8   0.122442  4.183364    0.573918  0.666667          1            0
# 9   0.061196  4.114007    0.472455  0.600000          1            0
# 10  0.054756  4.071192    0.438528  0.500000          1            0
# 11  0.032565  4.362786    0.613887  0.750000          1            0
# 12  0.051632  3.967691    0.356814  0.500000          1            0
# 13  0.041392  4.104994    0.327862  0.500000          1            0
# 14  0.078551  4.193994    0.505518  0.600000          1            0
# 15  0.031512  4.215689    0.437474  0.666667          1            0
# 16  0.117256  4.017881    0.398364  0.666667          1            0
# 17  0.081659  4.253645    0.507894  0.600000          1            0
# 18  0.115867  4.125343    0.590880  0.600000          1            0
# 19  0.048850  4.247332    0.551187  0.500000          1            0
# 20  0.028185  4.132190    0.519650  0.500000          1            0
# 21  0.050218  4.113274    0.486019  0.500000          1            0
# 22  0.097666  4.063319    0.363606  0.400000          1            0
# 23  0.110199  4.163800    0.453516  0.666667          1            0
# 24  0.111872  4.107763    0.491953  0.600000          1            0
# 25  0.120029  4.228678    0.604848  0.750000          1            0
# 26  0.038409  4.153473    0.369830  0.500000          1            0
# 27  0.070789  3.953237    0.392505  0.400000          1            0
# 28  0.069144  4.152290    0.528378  0.666667          1            0
# 29  0.040945  4.112331    0.689996  0.666667          1            0
# 30  0.108499  4.265631    0.596677  0.666667          1            0
# 31  0.069546  4.251238    0.507188  0.600000          1            0
# 32  0.133015  4.272721    0.624597  0.750000          1            0
# 33  0.070016  4.262088    0.546518  0.750000          1            0
# 34  0.062835  4.216272    0.416483  0.666667          1            0
# 35  0.030169  4.089525    0.602374  0.500000          1            0
# 36  0.036601  4.058340    0.344072  0.500000          1            0
# 37  0.140721  4.088876    0.582447  0.666667          1            0
# 38  0.029012  4.284839    0.594317  0.750000          1            0
# 39  0.061621  4.246925    0.462410  0.666667          1            0
# 40  0.053289  4.076342    0.449698  0.666667          1            0
# 41  0.052929  4.076536    0.334342  0.500000          1            0
# 42  0.095222  4.132731    0.570837  0.666667          1            0
# 43  0.100022  4.172839    0.491548  0.600000          1            0
# 44  0.092302  4.361000    0.597933  0.750000          1            0
# 45  0.097854  4.203975    0.440520  0.666667          1            0
# 46  0.033707  4.092379    0.436414  0.500000          1            0
# 47  0.046979  4.212138    0.506930  0.600000          1            0
# 48  0.082964  4.196264    0.551757  0.750000          1            0
# 49  0.025202  3.938912    0.380047  0.400000          1            0
#
#     Jaro-Winkler_rit  negT  negH  overlap_ent         clases  \
# 0           0.588889     0     0     0.250000  contradiction
# 1           0.550000     0     0     0.250000  contradiction
# 2           0.464286     0     0     0.333333  contradiction
# 3           0.588889     0     0     0.500000  contradiction
# 4           0.483333     0     0     0.333333  contradiction
# 5           0.658333     0     0     0.500000  contradiction
# 6           0.672619     0     0     0.333333  contradiction
# 7           0.438889     0     0     0.333333  contradiction
# 8           0.572222     0     0     0.333333  contradiction
# 9           0.600000     0     0     0.250000  contradiction
# 10          0.648810     0     0     0.285714  contradiction
# 11          0.425641     0     0     0.500000  contradiction
# 12          0.539683     0     0     0.250000  contradiction
# 13          0.450000     0     0     0.500000  contradiction
# 14          0.666667     0     0     0.500000  contradiction
# 15          0.438889     0     0     0.333333  contradiction
# 16          0.450000     0     0     0.333333  contradiction
# 17          0.680556     0     0     0.400000  contradiction
# 18          0.577778     0     0     0.333333  contradiction
# 19          0.694444     0     0     0.333333  contradiction
# 20          0.539683     0     0     0.250000  contradiction
# 21          0.630291     0     0     0.142857  contradiction
# 22          0.513889     0     0     0.250000  contradiction
# 23          0.527778     0     0     0.333333  contradiction
# 24          0.700000     0     0     0.400000  contradiction
# 25          0.583333     0     0     0.333333  contradiction
# 26          0.450000     0     0     0.250000  contradiction
# 27          0.500000     0     0     0.333333  contradiction
# 28          0.453704     0     0     0.333333  contradiction
# 29          0.472222     0     0     0.333333  contradiction
# 30          0.584707     0     0     0.400000  contradiction
# 31          0.455882     0     0     0.400000  contradiction
# 32          0.611111     0     0     0.500000  contradiction
# 33          0.503704     0     0     0.333333  contradiction
# 34          0.694444     0     0     0.333333  contradiction
# 35          0.550000     0     0     0.333333  contradiction
# 36          0.561905     0     0     0.250000  contradiction
# 37          0.511905     0     0     0.333333  contradiction
# 38          0.547619     0     0     0.333333  contradiction
# 39          0.492063     0     0     0.333333  contradiction
# 40          0.567460     0     0     0.333333  contradiction
# 41          0.600000     0     0     0.250000  contradiction
# 42          0.444444     0     0     0.333333  contradiction
# 43          0.666667     0     0     0.250000  contradiction
# 44          0.700000     0     0     0.200000  contradiction
# 45          0.611111     0     0     0.500000  contradiction
# 46          0.662037     0     0     0.333333  contradiction
# 47          0.495726     0     0     0.250000  contradiction
# 48          0.464286     0     0     0.333333  contradiction
# 49          0.662698     0     0     0.166667  contradiction
#
#                                            sentence_A  \
# 0     Women and children are playing on a paved road.
# 1   A man with a mallet about to hit a target to m...
# 2   A man playing a round of golf at the golf course.
# 3   A girl holding a stick looks back at the camer...
# 4   Several people are preparing to film a scene i...
# 5   An older man with a yellow blouse is reading s...
# 6   A group of people stand in a fancily decorated...
# 7   A man in camouflaged shorts, and a white t-shi...
# 8   A young boy wearing a backpack stands in front...
# 9   Two children running on the sidewalk along sid...
# 10  A shirtless man is sitting on the ground holdi...
# 11  A Caucasian young woman in a white hooded swea...
# 12  A man is standing on a big rock overlooking a ...
# 13  A man on a brown coat is talking to a man with...
# 14  A man is holding a cross with a photo of Jesus...
# 15  An older woman dressed in an ill-fitting yello...
# 16  A bird with blue and white feathers and a long...
# 17  A brown dog is jumping up to catch a green str...
# 18  The person is wearing a colorful and checkered...
# 19       Two women standing at a table at a job fair.
# 20  Two women looks over an item at a Chinese conv...
# 21  A man is throwing freesbies into the air and t...
# 22  A man driving a yellow train next to a highway...
# 23                       A man standing at a blue ATM
# 24          A man in glasses talking in a microphone.
# 25           A man poses in front of a run down house
# 26  This girl is outside, kicking leaves, in a fie...
# 27    One man drinking a beer while another man eats.
# 28  A woman sitting on a grassy hill hitting a ten...
# 29  Small girl in red, white and black dress looks...
# 30  A man with long hair, a mustache, and a beard ...
# 31  Four cute elderly lady friends are waiting tog...
# 32        Four men are playing on a stone paved area.
# 33  A young boy in a t-shirt, sweats and a red hat...
# 34  Three women run barefoot on the sand towards t...
# 35              woman in white walking on the street.
# 36  A man in a gray shirt with a beard prepares a ...
# 37  Three children and a woman stand near the wate...
# 38  A heavyset man running a Pro-Saw concrete saw ...
# 39  A man in a white tank top sitting down looking...
# 40         A man in black pants climbing a rock wall.
# 41  Three men talking at an entrepreneurs convention.
# 42  A man with tattoos on his arm, wearing a yello...
# 43  The little kids is jumping off a ledge and int...
# 44  A woman reading and cooking in the back of a SUV.
# 45  Several people are crowded together in a room ...
# 46  A man in a suit runs across an intersection wh...
# 47  A black man in a dress shirt is looking throug...
# 48  Two men are on a mechanical lift and inspect d...
# 49      4 men are sitting at a table deep in thought.
#
#                                            sentence_B
# 0          The people are playing cards at the table.
# 1                      A man sitting on a park bench.
# 2                            A man sits on the couch.
# 3             The girl is standing up holding a rock.
# 4                     The people are watching a game.
# 5            There is a young child reading on stage.
# 6   A group of people are sitting in the grass at ...
# 7                       The man is holding a balloon.
# 8                                A boy sits in a car.
# 9       Two children are indoors watching television.
# 10  There is a man in a suit jumping from a plane,...
# 11   The woman is running laps around the restaurant.
# 12           A man is playing Dance Dance Revolution.
# 13        The men are in their separate homes asleep.
# 14  The man is looking at the cross and walking away.
# 15                        A woman is lifting weights.
# 16                          A bird was taking a bath.
# 17      A brown dog is running to hide from the rain.
# 18              A person is wearing a dull grey suit.
# 19   Two women sitting next to each other on the bus.
# 20    Two women order food at the Italian restaurant.
# 21  A man throwing rocks into a lake while his dog...
# 22  A train driver with his hands full piloting th...
# 23                              a man walking his cat
# 24  The man in glasses is playing basketball with ...
# 25             The man is grilling in the front yard.
# 26                    A girl is building a snow fort.
# 27  A person is eating pizza while another is eati...
# 28                  A woman is standing on a chicken.
# 29                    The girl is wearing a swimsuit.
# 30  A man with long hair plays with his dog in the...
# 31      The ladies are sitting on top of a trash can.
# 32                      Four men are sitting outside.
# 33                        A young boy is eating cake.
# 34                      Women are sitting on a couch.
# 35                    a woman in red runs down a hall
# 36             A man is sitting at home on the couch.
# 37                     People are standing in a pool.
# 38                The heavyset man is using a hammer.
# 39                The man in is reading the newspaper
# 40                   The man is dancing on the ground
# 41         The men are watching a movie at a theater.
# 42                        The man sits on the ground.
# 43           Little kids are swinging on a swing set.
# 44          A woman cooks on the hood of her VW Golf.
# 45                          Some people walk outside.
# 46     A man is running in gym shorts and a tank top.
# 47        A black man plays golf with his colleagues.
# 48                   Two men are sleeping on the job.
# 49  The men are eating and laughing as they talk a...

# %% [markdown]
# # Predicciones correctas

# %%
for index,strings in df.iterrows():
    #print(strings["sentence1"],strings["sentence2"],strings['gold_label'])
    prompt = '''Example '''+str(index+1)+'''
    Text: '''+strings["sentence_A"]+'''
    Hypothesis: '''+ strings["sentence_B"]+'''
    features:
    sums:'''+ str(strings["sumas"])+'''
    negH:'''+ str(strings["negH"])+'''
    list_compability:'''+ str(strings["list_comp"])+'''
    list_incompability:'''+ str(strings["list_incomp"])+'''
    relation:'''+ str(strings["relation"])+'''
    entail:'''+ str(strings["entail"])+'''
    negT:'''+ str(strings["negT"])+'''
    mutinf:'''+ str(strings["mutinf_t"])+'''
    contradiction:'''+ str(strings["contradiction"])+'''
    no_matcheadas:'''+ str(strings["no_matcheadas"])+'''
    Jaro-Winkler_rit:'''+ str(strings["Jaro-Winkler_rit"])+'''
    simBoW:'''+ str(strings["simBoW"])+'''
    jaccard:'''+ str(strings["jaccard"])+'''
    overlap_ent:'''+ str(strings["overlap_ent"])+'''
    max_info_t:'''+ str(strings["max_info_t"])+''' 
    Answer:'''+ str(strings["clases"]).upper()+''' 
    '''
    print(prompt)
# Out:
# Example 1
#     Text: Women and children are playing on a paved road.
#     Hypothesis: The people are playing cards at the table.
#     features:
#     sums:0.0726584255695343
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5
#     negT:0
#     mutinf:4.0843409991188295
#     contradiction:0.0
#     no_matcheadas:0.75
#     Jaro-Winkler_rit:0.5888888888888889
#     simBoW:0.3651483716701107
#     jaccard:0.25
#     overlap_ent:0.25
#     max_info_t:0.4296835064888
#     Answer:CONTRADICTION
#
# Example 2
#     Text: A man with a mallet about to hit a target to make a bell ring at a carnival.
#     Hypothesis: A man sitting on a park bench.
#     features:
#     sums:0.0303195414599031
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5
#     negT:0
#     mutinf:4.06304192955344
#     contradiction:0.0
#     no_matcheadas:0.75
#     Jaro-Winkler_rit:0.5499999999999999
#     simBoW:0.316227766016838
#     jaccard:0.5
#     overlap_ent:0.25
#     max_info_t:0.3498696684837341
#     Answer:CONTRADICTION
#
# Example 3
#     Text: A man playing a round of golf at the golf course.
#     Hypothesis: A man sits on the couch.
#     features:
#     sums:0.0909391274054845
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6666666666666666
#     negT:0
#     mutinf:4.131163017224098
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.4642857142857142
#     simBoW:0.3333333333333332
#     jaccard:0.3333333333333333
#     overlap_ent:0.3333333333333333
#     max_info_t:0.4291686216990153
#     Answer:CONTRADICTION
#
# Example 4
#     Text: A girl holding a stick looks back at the camera while sitting among some trees and bushes.
#     Hypothesis: The girl is standing up holding a rock.
#     features:
#     sums:0.1304607656266954
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.75
#     negT:0
#     mutinf:4.343208183819807
#     contradiction:0.0
#     no_matcheadas:0.5
#     Jaro-Winkler_rit:0.5888888888888889
#     simBoW:0.4472135954999578
#     jaccard:0.25
#     overlap_ent:0.5
#     max_info_t:0.6456006169319153
#     Answer:CONTRADICTION
#
# Example 5
#     Text: Several people are preparing to film a scene involving a young schoolgirl and a young schoolboy.
#     Hypothesis: The people are watching a game.
#     features:
#     sums:0.0561707660003944
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6666666666666666
#     negT:0
#     mutinf:4.093555074128353
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.4833333333333333
#     simBoW:0.2886751345948128
#     jaccard:0.3333333333333333
#     overlap_ent:0.3333333333333333
#     max_info_t:0.4190560976664225
#     Answer:CONTRADICTION
#
# Example 6
#     Text: An older man with a yellow blouse is reading something while he stands on stage.
#     Hypothesis: There is a young child reading on stage.
#     features:
#     sums:0.1290799719946725
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.75
#     negT:0
#     mutinf:4.336449262885414
#     contradiction:0.0
#     no_matcheadas:0.5
#     Jaro-Winkler_rit:0.6583333333333333
#     simBoW:0.4743416490252569
#     jaccard:0.3333333333333333
#     overlap_ent:0.5
#     max_info_t:0.6337763667106628
#     Answer:CONTRADICTION
#
# Example 7
#     Text: A group of people stand in a fancily decorated room.
#     Hypothesis: A group of people are sitting in the grass at a football game.
#     features:
#     sums:0.1108575243916776
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5
#     negT:0
#     mutinf:4.023239645015244
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.6726190476190476
#     simBoW:0.4285714285714286
#     jaccard:0.25
#     overlap_ent:0.3333333333333333
#     max_info_t:0.4466188748677571
#     Answer:CONTRADICTION
#
# Example 8
#     Text: A man in camouflaged shorts, and a white t-shirt shines, another man's black shoes on a sidewalk.
#     Hypothesis: The man is holding a balloon.
#     features:
#     sums:0.0505121424794197
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6666666666666666
#     negT:0
#     mutinf:4.127776486566184
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.4388888888888889
#     simBoW:0.3441236008058427
#     jaccard:0.3333333333333333
#     overlap_ent:0.3333333333333333
#     max_info_t:0.4000030755996704
#     Answer:CONTRADICTION
#
# Example 9
#     Text: A young boy wearing a backpack stands in front of a vegetable vendor in a dirty street.
#     Hypothesis: A boy sits in a car.
#     features:
#     sums:0.122441832224528
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6666666666666666
#     negT:0
#     mutinf:4.183364178142671
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.5722222222222223
#     simBoW:0.3162277660168379
#     jaccard:0.3333333333333333
#     overlap_ent:0.3333333333333333
#     max_info_t:0.5739183823267618
#     Answer:CONTRADICTION
#
# Example 10
#     Text: Two children running on the sidewalk along side the street.
#     Hypothesis: Two children are indoors watching television.
#     features:
#     sums:0.061196219921112
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6
#     negT:0
#     mutinf:4.114006946425993
#     contradiction:0.0
#     no_matcheadas:0.75
#     Jaro-Winkler_rit:0.6
#     simBoW:0.4
#     jaccard:0.3333333333333333
#     overlap_ent:0.25
#     max_info_t:0.4724549770355224
#     Answer:CONTRADICTION
#
# Example 11
#     Text: A shirtless man is sitting on the ground holding fruit.
#     Hypothesis: There is a man in a suit jumping from a plane, holding a briefcase.
#     features:
#     sums:0.054756008916431
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5
#     negT:0
#     mutinf:4.071192284869372
#     contradiction:0.0
#     no_matcheadas:0.7142857142857143
#     Jaro-Winkler_rit:0.6488095238095238
#     simBoW:0.4008918628686366
#     jaccard:0.1666666666666666
#     overlap_ent:0.2857142857142857
#     max_info_t:0.4385275840759277
#     Answer:CONTRADICTION
#
# Example 12
#     Text: A Caucasian young woman in a white hooded sweatshirt sits at a table set for two in a lowly lit restaurant.
#     Hypothesis: The woman is running laps around the restaurant.
#     features:
#     sums:0.032564809689155
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.75
#     negT:0
#     mutinf:4.362785582608169
#     contradiction:0.0
#     no_matcheadas:0.5
#     Jaro-Winkler_rit:0.4256410256410256
#     simBoW:0.3721042037676254
#     jaccard:0.5
#     overlap_ent:0.5
#     max_info_t:0.6138867139816284
#     Answer:CONTRADICTION
#
# Example 13
#     Text: A man is standing on a big rock overlooking a valley.
#     Hypothesis: A man is playing Dance Dance Revolution.
#     features:
#     sums:0.0516318033138911
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5
#     negT:0
#     mutinf:3.967690587439261
#     contradiction:0.0
#     no_matcheadas:0.75
#     Jaro-Winkler_rit:0.5396825396825397
#     simBoW:0.2672612419124244
#     jaccard:0.3333333333333333
#     overlap_ent:0.25
#     max_info_t:0.3568140566349029
#     Answer:CONTRADICTION
#
# Example 14
#     Text: A man on a brown coat is talking to a man with black pants and a man in a suit.
#     Hypothesis: The men are in their separate homes asleep.
#     features:
#     sums:0.0413919101868357
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5
#     negT:0
#     mutinf:4.104993781042898
#     contradiction:0.0
#     no_matcheadas:0.5
#     Jaro-Winkler_rit:0.45
#     simBoW:0.4472135954999578
#     jaccard:0.5
#     overlap_ent:0.5
#     max_info_t:0.3278615772724151
#     Answer:CONTRADICTION
#
# Example 15
#     Text: A man is holding a cross with a photo of Jesus on it.
#     Hypothesis: The man is looking at the cross and walking away.
#     features:
#     sums:0.0785507524013519
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6
#     negT:0
#     mutinf:4.193994480554975
#     contradiction:0.0
#     no_matcheadas:0.5
#     Jaro-Winkler_rit:0.6666666666666666
#     simBoW:0.5
#     jaccard:0.5
#     overlap_ent:0.5
#     max_info_t:0.5055183887481689
#     Answer:CONTRADICTION
#
# Example 16
#     Text: An older woman dressed in an ill-fitting yellow shirt and blue plaid skirt is sitting on the ground next to two pails.
#     Hypothesis: A woman is lifting weights.
#     features:
#     sums:0.0315122604370117
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6666666666666666
#     negT:0
#     mutinf:4.215689038751719
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.4388888888888889
#     simBoW:0.2581988897471612
#     jaccard:0.3333333333333333
#     overlap_ent:0.3333333333333333
#     max_info_t:0.4374738534291585
#     Answer:CONTRADICTION
#
# Example 17
#     Text: A bird with blue and white feathers and a long pointy beak is flying through the air.
#     Hypothesis: A bird was taking a bath.
#     features:
#     sums:0.1172563177016046
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6666666666666666
#     negT:0
#     mutinf:4.017881215440879
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.45
#     simBoW:0.3162277660168379
#     jaccard:0.3333333333333333
#     overlap_ent:0.3333333333333333
#     max_info_t:0.3983636697133382
#     Answer:CONTRADICTION
#
# Example 18
#     Text: A brown dog is jumping up to catch a green strap in its mouth.
#     Hypothesis: A brown dog is running to hide from the rain.
#     features:
#     sums:0.0816590619938714
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6
#     negT:0
#     mutinf:4.253644858693088
#     contradiction:0.0
#     no_matcheadas:0.6
#     Jaro-Winkler_rit:0.6805555555555555
#     simBoW:0.4330127018922194
#     jaccard:0.3333333333333333
#     overlap_ent:0.4
#     max_info_t:0.5078940868377686
#     Answer:CONTRADICTION
#
# Example 19
#     Text: The person is wearing a colorful and checkered outfit
#     Hypothesis: A person is wearing a dull grey suit.
#     features:
#     sums:0.1158672046661377
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6
#     negT:0
#     mutinf:4.125342863712822
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.5777777777777778
#     simBoW:0.3651483716701107
#     jaccard:0.5
#     overlap_ent:0.3333333333333333
#     max_info_t:0.5908796310424804
#     Answer:CONTRADICTION
#
# Example 20
#     Text: Two women standing at a table at a job fair.
#     Hypothesis: Two women sitting next to each other on the bus.
#     features:
#     sums:0.0488495296902126
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5
#     negT:0
#     mutinf:4.247331545890668
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.6944444444444445
#     simBoW:0.4082482904638631
#     jaccard:0.3333333333333333
#     overlap_ent:0.3333333333333333
#     max_info_t:0.5511866807937622
#     Answer:CONTRADICTION
#
# Example 21
#     Text: Two women looks over an item at a Chinese convenience store.
#     Hypothesis: Two women order food at the Italian restaurant.
#     features:
#     sums:0.0281847034181867
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5
#     negT:0
#     mutinf:4.132189767481209
#     contradiction:0.0
#     no_matcheadas:0.75
#     Jaro-Winkler_rit:0.5396825396825397
#     simBoW:0.3086066999241839
#     jaccard:0.25
#     overlap_ent:0.25
#     max_info_t:0.5196500221888224
#     Answer:CONTRADICTION
#
# Example 22
#     Text: A man is throwing freesbies into the air and the border collie is catching them in the air.
#     Hypothesis: A man throwing rocks into a lake while his dog is sleeping.
#     features:
#     sums:0.0502179066340128
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5
#     negT:0
#     mutinf:4.113274187107531
#     contradiction:0.0
#     no_matcheadas:0.8571428571428571
#     Jaro-Winkler_rit:0.6302910052910052
#     simBoW:0.3418817293789138
#     jaccard:0.2
#     overlap_ent:0.1428571428571428
#     max_info_t:0.4860188961029053
#     Answer:CONTRADICTION
#
# Example 23
#     Text: A man driving a yellow train next to a highway talks on his cellphone.
#     Hypothesis: A train driver with his hands full piloting the train.
#     features:
#     sums:0.0976661562919616
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.4
#     negT:0
#     mutinf:4.063318878586747
#     contradiction:0.0
#     no_matcheadas:0.75
#     Jaro-Winkler_rit:0.5138888888888888
#     simBoW:0.375
#     jaccard:0.3333333333333333
#     overlap_ent:0.25
#     max_info_t:0.3636060953140259
#     Answer:CONTRADICTION
#
# Example 24
#     Text: A man standing at a blue ATM
#     Hypothesis: a man walking his cat
#     features:
#     sums:0.110199473798275
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6666666666666666
#     negT:0
#     mutinf:4.163799841444931
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.5277777777777778
#     simBoW:0.2886751345948128
#     jaccard:0.5
#     overlap_ent:0.3333333333333333
#     max_info_t:0.4535160859425862
#     Answer:CONTRADICTION
#
# Example 25
#     Text: A man in glasses talking in a microphone.
#     Hypothesis: The man in glasses is playing basketball with his friends.
#     features:
#     sums:0.1118718259036541
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6
#     negT:0
#     mutinf:4.10776311202461
#     contradiction:0.0
#     no_matcheadas:0.6
#     Jaro-Winkler_rit:0.7000000000000001
#     simBoW:0.5477225575051661
#     jaccard:0.4
#     overlap_ent:0.4
#     max_info_t:0.4919526100158691
#     Answer:CONTRADICTION
#
# Example 26
#     Text: A man poses in front of a run down house
#     Hypothesis: The man is grilling in the front yard.
#     features:
#     sums:0.1200290769338607
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.75
#     negT:0
#     mutinf:4.228677633688146
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.5833333333333334
#     simBoW:0.25
#     jaccard:0.3333333333333333
#     overlap_ent:0.3333333333333333
#     max_info_t:0.6048479080200195
#     Answer:CONTRADICTION
#
# Example 27
#     Text: This girl is outside, kicking leaves, in a field where there are trees in the background.
#     Hypothesis: A girl is building a snow fort.
#     features:
#     sums:0.0384087562561035
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5
#     negT:0
#     mutinf:4.1534728096337705
#     contradiction:0.0
#     no_matcheadas:0.75
#     Jaro-Winkler_rit:0.45
#     simBoW:0.2581988897471611
#     jaccard:0.3333333333333333
#     overlap_ent:0.25
#     max_info_t:0.369829773902893
#     Answer:CONTRADICTION
#
# Example 28
#     Text: One man drinking a beer while another man eats.
#     Hypothesis: A person is eating pizza while another is eating a snow cone
#     features:
#     sums:0.0707887458801269
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.4
#     negT:0
#     mutinf:3.953236719737788
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.5
#     simBoW:0.25
#     jaccard:0.25
#     overlap_ent:0.3333333333333333
#     max_info_t:0.3925045967102051
#     Answer:CONTRADICTION
#
# Example 29
#     Text: A woman sitting on a grassy hill hitting a tennis ball with a racket.
#     Hypothesis: A woman is standing on a chicken.
#     features:
#     sums:0.0691436321164171
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6666666666666666
#     negT:0
#     mutinf:4.152290445246844
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.4537037037037037
#     simBoW:0.3333333333333333
#     jaccard:0.3333333333333333
#     overlap_ent:0.3333333333333333
#     max_info_t:0.5283777316411337
#     Answer:CONTRADICTION
#
# Example 30
#     Text: Small girl in red, white and black dress looks at large silver orbs.
#     Hypothesis: The girl is wearing a swimsuit.
#     features:
#     sums:0.0409447809060414
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6666666666666666
#     negT:0
#     mutinf:4.112330770289067
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.4722222222222221
#     simBoW:0.2886751345948128
#     jaccard:0.5
#     overlap_ent:0.3333333333333333
#     max_info_t:0.6899956067403158
#     Answer:CONTRADICTION
#
# Example 31
#     Text: A man with long hair, a mustache, and a beard is holding a guitar and sitting in front of a USA flag.
#     Hypothesis: A man with long hair plays with his dog in the park.
#     features:
#     sums:0.1084992452101274
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6666666666666666
#     negT:0
#     mutinf:4.265631129393893
#     contradiction:0.0
#     no_matcheadas:0.6
#     Jaro-Winkler_rit:0.5847069597069597
#     simBoW:0.3903600291794133
#     jaccard:0.4
#     overlap_ent:0.4
#     max_info_t:0.5966765880584717
#     Answer:CONTRADICTION
#
# Example 32
#     Text: Four cute elderly lady friends are waiting together on a bench under a large tree, and a younger woman with blond curls and yellow skirt sits off to the side.
#     Hypothesis: The ladies are sitting on top of a trash can.
#     features:
#     sums:0.0695464599463674
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6
#     negT:0
#     mutinf:4.251238105440319
#     contradiction:0.0
#     no_matcheadas:0.6
#     Jaro-Winkler_rit:0.4558823529411764
#     simBoW:0.3638034375544994
#     jaccard:0.25
#     overlap_ent:0.4
#     max_info_t:0.5071876525878907
#     Answer:CONTRADICTION
#
# Example 33
#     Text: Four men are playing on a stone paved area.
#     Hypothesis: Four men are sitting outside.
#     features:
#     sums:0.1330147882302602
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.75
#     negT:0
#     mutinf:4.272720574468558
#     contradiction:0.0
#     no_matcheadas:0.5
#     Jaro-Winkler_rit:0.611111111111111
#     simBoW:0.4082482904638631
#     jaccard:0.5
#     overlap_ent:0.5
#     max_info_t:0.6245973706245422
#     Answer:CONTRADICTION
#
# Example 34
#     Text: A young boy in a t-shirt, sweats and a red hat, skateboarding in a skateboard arena, with an audience on the side and blue skies above.
#     Hypothesis: A young boy is eating cake.
#     features:
#     sums:0.0700158817427498
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.75
#     negT:0
#     mutinf:4.26208813431214
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.5037037037037037
#     simBoW:0.2631174057921088
#     jaccard:0.3333333333333333
#     overlap_ent:0.3333333333333333
#     max_info_t:0.546518087387085
#     Answer:CONTRADICTION
#
# Example 35
#     Text: Three women run barefoot on the sand towards the water.
#     Hypothesis: Women are sitting on a couch.
#     features:
#     sums:0.0628354147904449
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6666666666666666
#     negT:0
#     mutinf:4.216271986853314
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.6944444444444445
#     simBoW:0.4082482904638631
#     jaccard:0.3333333333333333
#     overlap_ent:0.3333333333333333
#     max_info_t:0.4164833227793376
#     Answer:CONTRADICTION
#
# Example 36
#     Text: woman in white walking on the street.
#     Hypothesis: a woman in red runs down a hall
#     features:
#     sums:0.0301694720983505
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5
#     negT:0
#     mutinf:4.089525045141757
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.5499999999999999
#     simBoW:0.2236067977499789
#     jaccard:0.3333333333333333
#     overlap_ent:0.3333333333333333
#     max_info_t:0.6023743748664856
#     Answer:CONTRADICTION
#
# Example 37
#     Text: A man in a gray shirt with a beard prepares a recipe.
#     Hypothesis: A man is sitting at home on the couch.
#     features:
#     sums:0.0366009051601091
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5
#     negT:0
#     mutinf:4.058339857270022
#     contradiction:0.0
#     no_matcheadas:0.75
#     Jaro-Winkler_rit:0.5619047619047619
#     simBoW:0.3380617018914067
#     jaccard:0.25
#     overlap_ent:0.25
#     max_info_t:0.3440722823143005
#     Answer:CONTRADICTION
#
# Example 38
#     Text: Three children and a woman stand near the water's edge.
#     Hypothesis: People are standing in a pool.
#     features:
#     sums:0.1407211754057142
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6666666666666666
#     negT:0
#     mutinf:4.088876183824923
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.5119047619047619
#     simBoW:0.3779644730092272
#     jaccard:0.3333333333333333
#     overlap_ent:0.3333333333333333
#     max_info_t:0.5824471712112427
#     Answer:CONTRADICTION
#
# Example 39
#     Text: A heavyset man running a Pro-Saw concrete saw with a piece of white construction equipment in the background.
#     Hypothesis: The heavyset man is using a hammer.
#     features:
#     sums:0.0290122280518213
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.75
#     negT:0
#     mutinf:4.284839268817739
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.5476190476190476
#     simBoW:0.4008918628686366
#     jaccard:0.3333333333333333
#     overlap_ent:0.3333333333333333
#     max_info_t:0.594316840171814
#     Answer:CONTRADICTION
#
# Example 40
#     Text: A man in a white tank top sitting down looking at a laptop.
#     Hypothesis: The man in is reading the newspaper
#     features:
#     sums:0.0616207768519719
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6666666666666666
#     negT:0
#     mutinf:4.246925254749585
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.4920634920634921
#     simBoW:0.2182178902359923
#     jaccard:0.3333333333333333
#     overlap_ent:0.3333333333333333
#     max_info_t:0.46241029103597
#     Answer:CONTRADICTION
#
# Example 41
#     Text: A man in black pants climbing a rock wall.
#     Hypothesis: The man is dancing on the ground
#     features:
#     sums:0.0532892379495832
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6666666666666666
#     negT:0
#     mutinf:4.076342254391551
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.5674603174603174
#     simBoW:0.2182178902359923
#     jaccard:0.3333333333333333
#     overlap_ent:0.3333333333333333
#     max_info_t:0.4496984481811523
#     Answer:CONTRADICTION
#
# Example 42
#     Text: Three men talking at an entrepreneurs convention.
#     Hypothesis: The men are watching a movie at a theater.
#     features:
#     sums:0.0529286980628967
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5
#     negT:0
#     mutinf:4.076536364900064
#     contradiction:0.0
#     no_matcheadas:0.75
#     Jaro-Winkler_rit:0.6
#     simBoW:0.4
#     jaccard:0.25
#     overlap_ent:0.25
#     max_info_t:0.3343416452407837
#     Answer:CONTRADICTION
#
# Example 43
#     Text: A man with tattoos on his arm, wearing a yellow shirt and black helmet is standing in a room.
#     Hypothesis: The man sits on the ground.
#     features:
#     sums:0.09522172609965
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6666666666666666
#     negT:0
#     mutinf:4.132731353160414
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.4444444444444444
#     simBoW:0.2886751345948128
#     jaccard:0.3333333333333333
#     overlap_ent:0.3333333333333333
#     max_info_t:0.5708374977111816
#     Answer:CONTRADICTION
#
# Example 44
#     Text: The little kids is jumping off a ledge and into the dirt below it.
#     Hypothesis: Little kids are swinging on a swing set.
#     features:
#     sums:0.1000218361616134
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6
#     negT:0
#     mutinf:4.172839082169671
#     contradiction:0.0
#     no_matcheadas:0.75
#     Jaro-Winkler_rit:0.6666666666666666
#     simBoW:0.5
#     jaccard:0.3333333333333333
#     overlap_ent:0.25
#     max_info_t:0.4915476322174072
#     Answer:CONTRADICTION
#
# Example 45
#     Text: A woman reading and cooking in the back of a SUV.
#     Hypothesis: A woman cooks on the hood of her VW Golf.
#     features:
#     sums:0.0923019170761108
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.75
#     negT:0
#     mutinf:4.36100002012255
#     contradiction:0.0
#     no_matcheadas:0.8
#     Jaro-Winkler_rit:0.7000000000000001
#     simBoW:0.5477225575051661
#     jaccard:0.5
#     overlap_ent:0.2
#     max_info_t:0.5979328155517578
#     Answer:CONTRADICTION
#
# Example 46
#     Text: Several people are crowded together in a room with three large fans over them.
#     Hypothesis: Some people walk outside.
#     features:
#     sums:0.0978544677297274
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6666666666666666
#     negT:0
#     mutinf:4.203974586715758
#     contradiction:0.0
#     no_matcheadas:0.5
#     Jaro-Winkler_rit:0.611111111111111
#     simBoW:0.4082482904638631
#     jaccard:0.5
#     overlap_ent:0.5
#     max_info_t:0.4405200481414795
#     Answer:CONTRADICTION
#
# Example 47
#     Text: A man in a suit runs across an intersection while a large group of people assembles.
#     Hypothesis: A man is running in gym shorts and a tank top.
#     features:
#     sums:0.0337071567773819
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.5
#     negT:0
#     mutinf:4.092379459279445
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.6620370370370371
#     simBoW:0.4082482904638631
#     jaccard:0.5
#     overlap_ent:0.3333333333333333
#     max_info_t:0.4364143212636311
#     Answer:CONTRADICTION
#
# Example 48
#     Text: A black man in a dress shirt is looking through a microscope, while a poster about blood cells is on the wall in the background.
#     Hypothesis: A black man plays golf with his colleagues.
#     features:
#     sums:0.0469793092120777
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.6
#     negT:0
#     mutinf:4.21213773596066
#     contradiction:0.0
#     no_matcheadas:0.75
#     Jaro-Winkler_rit:0.4957264957264957
#     simBoW:0.3396831102433787
#     jaccard:0.25
#     overlap_ent:0.25
#     max_info_t:0.5069299697875976
#     Answer:CONTRADICTION
#
# Example 49
#     Text: Two men are on a mechanical lift and inspect damages on a wall.
#     Hypothesis: Two men are sleeping on the job.
#     features:
#     sums:0.0829636412007468
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.75
#     negT:0
#     mutinf:4.196263926915143
#     contradiction:0.0
#     no_matcheadas:0.6666666666666666
#     Jaro-Winkler_rit:0.4642857142857142
#     simBoW:0.3779644730092272
#     jaccard:0.3333333333333333
#     overlap_ent:0.3333333333333333
#     max_info_t:0.5517573356628418
#     Answer:CONTRADICTION
#
# Example 50
#     Text: 4 men are sitting at a table deep in thought.
#     Hypothesis: The men are eating and laughing as they talk about their day.
#     features:
#     sums:0.0252021074295043
#     negH:0
#     list_compability:1
#     list_incompability:0
#     relation:2
#     entail:0.4
#     negT:0
#     mutinf:3.938912218127011
#     contradiction:0.0
#     no_matcheadas:0.8333333333333334
#     Jaro-Winkler_rit:0.6626984126984127
#     simBoW:0.3086066999241839
#     jaccard:0.2
#     overlap_ent:0.1666666666666666
#     max_info_t:0.380047082901001
#     Answer:CONTRADICTION
